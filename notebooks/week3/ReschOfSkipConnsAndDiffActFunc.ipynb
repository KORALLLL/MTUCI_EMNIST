# %% [markdown]
# <a href="https://colab.research.google.com/github/KORALLLL/MTUCI_EMNIST/blob/Kirill/notebooks/week3/ReschOfSkipConnsAndDiffActFunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model

# %% [markdown]
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# # Hyperparameters

# %% [markdown]
# train dataset: MNIST + EMNIST letters
#
# test dataset: dataset of DreamTeam
#
# training sample size: 36960
#
# validation sample size: 30800
#
# testing sample size: 16784
#
# loss finction: Cross Entropy Loss
#
# optimizer: adam
#
# learning rate: 0.001
#
# batch size: 1120
#
# epoch number: ??

# %% [markdown]
# # Module importation

# %%
import torch
import torchvision.datasets
import torchvision.transforms as transforms
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as bar
import pickle
import numpy as np
import scipy.stats as stats

# %% [markdown]
# # Git cloning

# %%
# !git clone https://github.com/KORALLLL/MTUCI_EMNIST.git
# Out:
# Cloning into 'MTUCI_EMNIST'...
# remote: Enumerating objects: 36470, done.
# remote: Counting objects: 100% (12830/12830), done.
# remote: Compressing objects: 100% (12666/12666), done.
# remote: Total 36470 (delta 176), reused 12797 (delta 157), pack-reused 23640
# Receiving objects: 100% (36470/36470), 128.14 MiB | 28.17 MiB/s, done.
# Resolving deltas: 100% (461/461), done.

# %% [markdown]
# # Dataset preparation

# %%
emnist_train = torchvision.datasets.EMNIST('./', split='letters', download = True, train = True)
mnist_train = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = True)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

emnist_train_data = emnist_train.data
mnist_train_data = mnist_train.data
train_data = torch.cat([emnist_train_data[:24960], mnist_train_data[:12000]], dim=0).float().unsqueeze(1).to(device) / 255

temp_emnist_train_labels = emnist_train.targets[:24960]
emnist_train_labels = []

for i in range(len(temp_emnist_train_labels)):
  if temp_emnist_train_labels[i]==15:
    emnist_train_labels.append(torch.tensor(0))
  elif temp_emnist_train_labels[i]>15:
    emnist_train_labels.append(temp_emnist_train_labels[i]+8)
  else:
    emnist_train_labels.append(temp_emnist_train_labels[i]+9)

mnist_train_labels = mnist_train.targets
train_labels = torch.cat([torch.stack(emnist_train_labels[:24960]), mnist_train_labels[:12000]], dim=0).to(device)

file = open('MTUCI_EMNIST/dataset.pkl', 'rb')
test_dataset = pickle.load(file)
file.close()

test_data = test_dataset['data'].numpy()
test_data = np.flip(test_data, axis = 3)
test_data = np.rot90(test_data, k=1, axes=(2,3))
test_data = 1 - test_data
test_data = torch.from_numpy(test_data).float().to(device)
test_labels = test_dataset['targets'].to(device)
# Out:
# ...
# 100%|██████████| 561753746/561753746 [00:06<00:00, 92871381.36it/s]
# Extracting ./EMNIST/raw/gzip.zip to ./EMNIST/raw

# %% [markdown]
# # Configuration nets

# %%
class Lenet1(torch.nn.Module):
  def __init__(self):
    super(Lenet1, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = self.pool1(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %%
class Lenet2(torch.nn.Module):
  def __init__(self):
    super(Lenet2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    skip_conn1 = x

    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = torch.add(x, skip_conn1)

    x = self.conv4(x)
    x = self.act4(x)
    skip_conn2 = x

    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = torch.add(x, skip_conn2)

    x = self.pool1(x)
    x = self.act7(x)

    x = self.conv7(x)
    x = self.act8(x)
    skip_conn3 = x

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = torch.add(x, skip_conn3)

    x = self.conv10(x)
    x = self.act11(x)
    skip_conn4 = x

    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = torch.add(x, skip_conn4)

    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %% [markdown]
# # test train

# %% [markdown]
# ## net 1

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet1().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
batch_size = 1120

for epoch in bar(range(300), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
# Out:
# <ipython-input-15-d917dbeb208d>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(300), desc='learning'):
# learning:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)

plt.ylim(0.68, 0.72)
# Out:
# (0.68, 0.72)

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet2().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
batch_size = 1120

for epoch in bar(range(1000), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
# Out:
# <ipython-input-29-323766e1000a>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(1000), desc='learning'):
# learning:   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(1000), test_accuracy_history)
plt.xlim(10, 100)
plt.ylim(0.67, 0.735)
# Out:
# (0.67, 0.735)

# %%
nets = [Lenet1, Lenet2]

for net in bar(range(6), desc = 'nets'):
  accuracy_net = []
  for experiment in bar(range(20), desc = 'sample eperimnet'):

    loss = torch.nn.CrossEntropyLoss()
    lenet = nets[net]().to(device)
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(80):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()

    test_preds = lenet.forward(test_data)
    accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
    accuracy_net.append(accuracy)
    print(accuracy)
  print(f'accuracy of {net} net:')
  print(*accuracy_net)
# Out:
# <ipython-input-35-e34ff1398f52>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for net in bar(range(6), desc = 'nets'):
# nets:   0%|          | 0/6 [00:00<?, ?it/s]
# <ipython-input-35-e34ff1398f52>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(20), desc = 'sample eperimnet'):
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# tensor(0.6319)
# tensor(0.7015)
# tensor(0.6650)
# tensor(0.7108)
# tensor(0.7125)
# tensor(0.0499)
# tensor(0.6992)
# tensor(0.6712)
# tensor(0.6233)
# tensor(0.7115)
# tensor(0.7047)
# tensor(0.7029)
# tensor(0.0499)
# tensor(0.0499)
# tensor(0.7155)
# tensor(0.6982)
# tensor(0.0499)
# tensor(0.6982)
# tensor(0.5890)
# tensor(0.6816)
# accuracy of 0 net:
# ...

# %% [markdown]
# net1
#
# tensor(0.6319) tensor(0.7015) tensor(0.6650) tensor(0.7108) tensor(0.7125) tensor(0.0499) tensor(0.6992) tensor(0.6712) tensor(0.6233) tensor(0.7115) tensor(0.7047) tensor(0.7029) tensor(0.0499) tensor(0.0499) tensor(0.7155) tensor(0.6982) tensor(0.0499) tensor(0.6982) tensor(0.5890) tensor(0.6816)
#
# net2
#
# tensor(0.7043) tensor(0.7259) tensor(0.7158) tensor(0.7234) tensor(0.7279) tensor(0.6847) tensor(0.6954) tensor(0.7326) tensor(0.6870) tensor(0.7392) tensor(0.7218) tensor(0.6957) tensor(0.6936) tensor(0.7039) tensor(0.7274) tensor(0.7235) tensor(0.6849) tensor(0.7223) tensor(0.7006) tensor(0.7126)

# %%
sample1 = "tensor(0.6319) tensor(0.7015) tensor(0.6650) tensor(0.7108) tensor(0.7125) tensor(0.0499) tensor(0.6992) tensor(0.6712) tensor(0.6233) tensor(0.7115) tensor(0.7047) tensor(0.7029) tensor(0.0499) tensor(0.0499) tensor(0.7155) tensor(0.6982) tensor(0.0499) tensor(0.6982) tensor(0.5890) tensor(0.6816)"
sample2 = "tensor(0.7043) tensor(0.7259) tensor(0.7158) tensor(0.7234) tensor(0.7279) tensor(0.6847) tensor(0.6954) tensor(0.7326) tensor(0.6870) tensor(0.7392) tensor(0.7218) tensor(0.6957) tensor(0.6936) tensor(0.7039) tensor(0.7274) tensor(0.7235) tensor(0.6849) tensor(0.7223) tensor(0.7006) tensor(0.7126)"

# %%
samples = [sample1, sample2]
for i in range(len(samples)):
  samples[i] = samples[i].replace("tensor(", '')
  samples[i] = samples[i].replace(')', '')
  samples[i] = [float(j) for j in samples[i].split(" ")]

# %%
plt.figure(figsize = (16., 6.))
plt.boxplot(samples)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x794418586020>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7944185850c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x794418586200>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x794418586c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x794418584ee0>,
# ...
#  'means': []}

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.004091758103493962

# %% [markdown]
# Затухающий градиент пропал. Точность увеличилась

# %% [markdown]
# ## second investigation

# %%
class Lenet2(torch.nn.Module):
  def __init__(self, act_func):
    super(Lenet2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = act_func()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = act_func()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = act_func()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = act_func()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = act_func()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = act_func()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act7 = act_func()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = act_func()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = act_func()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = act_func()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = act_func()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = act_func()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = act_func()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act14 = act_func()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = act_func()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = act_func()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    skip_conn1 = x

    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = torch.add(x, skip_conn1)

    x = self.conv4(x)
    x = self.act4(x)
    skip_conn2 = x

    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = torch.add(x, skip_conn2)

    x = self.pool1(x)
    x = self.act7(x)

    x = self.conv7(x)
    x = self.act8(x)
    skip_conn3 = x

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = torch.add(x, skip_conn3)

    x = self.conv10(x)
    x = self.act11(x)
    skip_conn4 = x

    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = torch.add(x, skip_conn4)

    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %%
activation_functions = [torch.nn.ELU, torch.nn.LeakyReLU, torch.nn.PReLU, torch.nn.ReLU, torch.nn.ReLU6, torch.nn.SELU, torch.nn.CELU, torch.nn.GELU, torch.nn.Tanh, torch.nn.GLU]

# %%
for af in bar(range(6, len(activation_functions)), desc = 'activation functions'):
  if af==6:
    iterator =
  accuracy_act_func = []
  for experiment in bar(range(20), desc = 'sample eperimnet'):

    loss = torch.nn.CrossEntropyLoss()
    lenet = Lenet2(act_func=activation_functions[af]).to(device)
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(80):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()
      torch.cuda.empty_cache()

    with torch.no_grad():
      test_preds = lenet.forward(test_data)
      accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
      accuracy_act_func.append(accuracy)
      print(accuracy)
  print(f'accuracy of {af} net:')
  print(*accuracy_act_func)
# Out:
# <ipython-input-7-47a3547804b0>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for af in bar(range(1, len(activation_functions)), desc = 'activation functions'):
# activation functions:   0%|          | 0/9 [00:00<?, ?it/s]
# <ipython-input-7-47a3547804b0>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(20), desc = 'sample eperimnet'):
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# tensor(0.7114)
# tensor(0.6939)
# tensor(0.6802)
# tensor(0.6970)
# tensor(0.6805)
# tensor(0.7091)
# tensor(0.7129)
# tensor(0.6941)
# tensor(0.6886)
# tensor(0.7129)
# tensor(0.6751)
# tensor(0.6869)
# tensor(0.6519)
# tensor(0.7093)
# tensor(0.6703)
# tensor(0.6464)
# tensor(0.7270)
# tensor(0.6889)
# tensor(0.6898)
# tensor(0.7110)
# accuracy of 1 net:
# ...

# %% [markdown]
# af0
#
# tensor(0.6912)
# tensor(0.6718)
# tensor(0.6985)
# tensor(0.7092)
# tensor(0.6933)
# tensor(0.7028)
# tensor(0.6924)
# tensor(0.6684)
# tensor(0.6947)
# tensor(0.6839)
# tensor(0.6892)
# tensor(0.7017)
# tensor(0.7018)
# tensor(0.7204)
# tensor(0.7064)
# tensor(0.6974)
# tensor(0.7146)
# tensor(0.6876)
# tensor(0.7133)
# tensor(0.6833)
#
# af1
#
# tensor(0.7114) tensor(0.6939) tensor(0.6802) tensor(0.6970) tensor(0.6805) tensor(0.7091) tensor(0.7129) tensor(0.6941) tensor(0.6886) tensor(0.7129) tensor(0.6751) tensor(0.6869) tensor(0.6519) tensor(0.7093) tensor(0.6703) tensor(0.6464) tensor(0.7270) tensor(0.6889) tensor(0.6898) tensor(0.7110)
#
# af2
#
# tensor(0.6764) tensor(0.6633) tensor(0.6781) tensor(0.6834) tensor(0.6701) tensor(0.6671) tensor(0.6728) tensor(0.6570) tensor(0.6646) tensor(0.6814) tensor(0.6736) tensor(0.6798) tensor(0.6641) tensor(0.6612) tensor(0.6519) tensor(0.6760) tensor(0.6569) tensor(0.6911) tensor(0.6894) tensor(0.6756)
#
# af3
#
# tensor(0.6924) tensor(0.7133) tensor(0.7078) tensor(0.6991) tensor(0.7210) tensor(0.6940) tensor(0.7366) tensor(0.7079) tensor(0.6709) tensor(0.6975) tensor(0.6992) tensor(0.7266) tensor(0.6937) tensor(0.7010) tensor(0.6987) tensor(0.7033) tensor(0.7154) tensor(0.7150) tensor(0.7137) tensor(0.6968)
#
# af4
#
# tensor(0.7300) tensor(0.7620) tensor(0.7281) tensor(0.7417) tensor(0.7097) tensor(0.7332) tensor(0.7361) tensor(0.7244) tensor(0.7577) tensor(0.7593) tensor(0.7095) tensor(0.7339) tensor(0.7339) tensor(0.7202) tensor(0.7383) tensor(0.7062) tensor(0.7369) tensor(0.7363) tensor(0.7208) tensor(0.7325)
#
#
#
# af5
#
# tensor(0.7082) tensor(0.7242) tensor(0.7182) tensor(0.6789) tensor(0.6830) tensor(0.7045) tensor(0.7020) tensor(0.6929) tensor(0.7188) tensor(0.6783) tensor(0.7197) tensor(0.7034) tensor(0.6957) tensor(0.7124) tensor(0.7074) tensor(0.7009) tensor(0.7009) tensor(0.6973) tensor(0.7068) tensor(0.6872)
#
# af6
#
# tensor(0.6882)
# tensor(0.7127)
# tensor(0.6937)
# tensor(0.6841)
# tensor(0.6803)
# tensor(0.6870)
# tensor(0.6999)
# tensor(0.6918)
# tensor(0.6951)
# tensor(0.7052)
# tensor(0.7066)
# tensor(0.7029)
# tensor(0.6979)
# tensor(0.7015) tensor(0.6748) tensor(0.6924) tensor(0.6906) tensor(0.6965) tensor(0.7082) tensor(0.7047)
#
# af7
#
# tensor(0.6954) tensor(0.6903) tensor(0.7216) tensor(0.7172) tensor(0.7086) tensor(0.7349) tensor(0.6610) tensor(0.7022) tensor(0.7379) tensor(0.6896) tensor(0.6421) tensor(0.7185) tensor(0.7121) tensor(0.6983) tensor(0.6921) tensor(0.6942) tensor(0.7032) tensor(0.7172) tensor(0.7317) tensor(0.6990)
#
# af8
# tensor(0.7090) tensor(0.7148) tensor(0.7104) tensor(0.7193) tensor(0.6960) tensor(0.7185) tensor(0.7216) tensor(0.7119) tensor(0.7076) tensor(0.7124) tensor(0.7338) tensor(0.6952) tensor(0.7175) tensor(0.6889) tensor(0.7057) tensor(0.7277) tensor(0.7143) tensor(0.7093) tensor(0.7181) tensor(0.7108)

# %%
for af in bar(range(8, len(activation_functions)), desc = 'activation functions'):
  if af==6:
    iterator = 7
  else:
    iterator = 20
  accuracy_act_func = []
  for experiment in bar(range(iterator), desc = 'sample eperimnet'):

    loss = torch.nn.CrossEntropyLoss()
    lenet = Lenet2(act_func=activation_functions[af]).to(device)
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(80):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()
      torch.cuda.empty_cache()

    with torch.no_grad():
      test_preds = lenet.forward(test_data)
      accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
      accuracy_act_func.append(accuracy)
      print(accuracy)
  print(f'accuracy of {af} net:')
  print(*accuracy_act_func)
# Out:
# <ipython-input-8-451f051994f5>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for af in bar(range(6, len(activation_functions)), desc = 'activation functions'):
# activation functions:   0%|          | 0/4 [00:00<?, ?it/s]
# <ipython-input-8-451f051994f5>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(iterator), desc = 'sample eperimnet'):
# sample eperimnet:   0%|          | 0/7 [00:00<?, ?it/s]
# tensor(0.7015)
# tensor(0.6748)
# tensor(0.6924)
# tensor(0.6906)
# tensor(0.6965)
# tensor(0.7082)
# tensor(0.7047)
# accuracy of 6 net:
# tensor(0.7015) tensor(0.6748) tensor(0.6924) tensor(0.6906) tensor(0.6965) tensor(0.7082) tensor(0.7047)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# tensor(0.6954)
# tensor(0.6903)
# tensor(0.7216)
# tensor(0.7172)
# ...

# %% [markdown]
# af0
#
# tensor(0.6912)
# tensor(0.6718)
# tensor(0.6985)
# tensor(0.7092)
# tensor(0.6933)
# tensor(0.7028)
# tensor(0.6924)
# tensor(0.6684)
# tensor(0.6947)
# tensor(0.6839)
# tensor(0.6892)
# tensor(0.7017)
# tensor(0.7018)
# tensor(0.7204)
# tensor(0.7064)
# tensor(0.6974)
# tensor(0.7146)
# tensor(0.6876)
# tensor(0.7133)
# tensor(0.6833)
#
# af1
#
# tensor(0.7114) tensor(0.6939) tensor(0.6802) tensor(0.6970) tensor(0.6805) tensor(0.7091) tensor(0.7129) tensor(0.6941) tensor(0.6886) tensor(0.7129) tensor(0.6751) tensor(0.6869) tensor(0.6519) tensor(0.7093) tensor(0.6703) tensor(0.6464) tensor(0.7270) tensor(0.6889) tensor(0.6898) tensor(0.7110)
#
# af2
#
# tensor(0.6764) tensor(0.6633) tensor(0.6781) tensor(0.6834) tensor(0.6701) tensor(0.6671) tensor(0.6728) tensor(0.6570) tensor(0.6646) tensor(0.6814) tensor(0.6736) tensor(0.6798) tensor(0.6641) tensor(0.6612) tensor(0.6519) tensor(0.6760) tensor(0.6569) tensor(0.6911) tensor(0.6894) tensor(0.6756)
#
# af3
#
# tensor(0.6924) tensor(0.7133) tensor(0.7078) tensor(0.6991) tensor(0.7210) tensor(0.6940) tensor(0.7366) tensor(0.7079) tensor(0.6709) tensor(0.6975) tensor(0.6992) tensor(0.7266) tensor(0.6937) tensor(0.7010) tensor(0.6987) tensor(0.7033) tensor(0.7154) tensor(0.7150) tensor(0.7137) tensor(0.6968)
#
# af4
#
# tensor(0.7300) tensor(0.7620) tensor(0.7281) tensor(0.7417) tensor(0.7097) tensor(0.7332) tensor(0.7361) tensor(0.7244) tensor(0.7577) tensor(0.7593) tensor(0.7095) tensor(0.7339) tensor(0.7339) tensor(0.7202) tensor(0.7383) tensor(0.7062) tensor(0.7369) tensor(0.7363) tensor(0.7208) tensor(0.7325)
#
#
#
# af5
#
# tensor(0.7082) tensor(0.7242) tensor(0.7182) tensor(0.6789) tensor(0.6830) tensor(0.7045) tensor(0.7020) tensor(0.6929) tensor(0.7188) tensor(0.6783) tensor(0.7197) tensor(0.7034) tensor(0.6957) tensor(0.7124) tensor(0.7074) tensor(0.7009) tensor(0.7009) tensor(0.6973) tensor(0.7068) tensor(0.6872)
#
# af6
#
# tensor(0.6882)
# tensor(0.7127)
# tensor(0.6937)
# tensor(0.6841)
# tensor(0.6803)
# tensor(0.6870)
# tensor(0.6999)
# tensor(0.6918)
# tensor(0.6951)
# tensor(0.7052)
# tensor(0.7066)
# tensor(0.7029)
# tensor(0.6979)
# tensor(0.7015) tensor(0.6748) tensor(0.6924) tensor(0.6906) tensor(0.6965) tensor(0.7082) tensor(0.7047)
#
# af7
#
# tensor(0.6954) tensor(0.6903) tensor(0.7216) tensor(0.7172) tensor(0.7086) tensor(0.7349) tensor(0.6610) tensor(0.7022) tensor(0.7379) tensor(0.6896) tensor(0.6421) tensor(0.7185) tensor(0.7121) tensor(0.6983) tensor(0.6921) tensor(0.6942) tensor(0.7032) tensor(0.7172) tensor(0.7317) tensor(0.6990)
#
# af8
# tensor(0.7090) tensor(0.7148) tensor(0.7104) tensor(0.7193) tensor(0.6960) tensor(0.7185) tensor(0.7216) tensor(0.7119) tensor(0.7076) tensor(0.7124) tensor(0.7338) tensor(0.6952) tensor(0.7175) tensor(0.6889) tensor(0.7057) tensor(0.7277) tensor(0.7143) tensor(0.7093) tensor(0.7181) tensor(0.7108)

# %%
sample0 = "tensor(0.6912) tensor(0.6718) tensor(0.6985) tensor(0.7092) tensor(0.6933) tensor(0.7028) tensor(0.6924) tensor(0.6684) tensor(0.6947) tensor(0.6839) tensor(0.6892) tensor(0.7017) tensor(0.7018) tensor(0.7204) tensor(0.7064) tensor(0.6974) tensor(0.7146) tensor(0.6876) tensor(0.7133) tensor(0.6833)"
sample1 = "tensor(0.7114) tensor(0.6939) tensor(0.6802) tensor(0.6970) tensor(0.6805) tensor(0.7091) tensor(0.7129) tensor(0.6941) tensor(0.6886) tensor(0.7129) tensor(0.6751) tensor(0.6869) tensor(0.6519) tensor(0.7093) tensor(0.6703) tensor(0.6464) tensor(0.7270) tensor(0.6889) tensor(0.6898) tensor(0.7110)"
sample2 = "tensor(0.6764) tensor(0.6633) tensor(0.6781) tensor(0.6834) tensor(0.6701) tensor(0.6671) tensor(0.6728) tensor(0.6570) tensor(0.6646) tensor(0.6814) tensor(0.6736) tensor(0.6798) tensor(0.6641) tensor(0.6612) tensor(0.6519) tensor(0.6760) tensor(0.6569) tensor(0.6911) tensor(0.6894) tensor(0.6756)"
sample3 = "tensor(0.6924) tensor(0.7133) tensor(0.7078) tensor(0.6991) tensor(0.7210) tensor(0.6940) tensor(0.7366) tensor(0.7079) tensor(0.6709) tensor(0.6975) tensor(0.6992) tensor(0.7266) tensor(0.6937) tensor(0.7010) tensor(0.6987) tensor(0.7033) tensor(0.7154) tensor(0.7150) tensor(0.7137) tensor(0.6968)"
sample4 = "tensor(0.7300) tensor(0.7620) tensor(0.7281) tensor(0.7417) tensor(0.7097) tensor(0.7332) tensor(0.7361) tensor(0.7244) tensor(0.7577) tensor(0.7593) tensor(0.7095) tensor(0.7339) tensor(0.7339) tensor(0.7202) tensor(0.7383) tensor(0.7062) tensor(0.7369) tensor(0.7363) tensor(0.7208) tensor(0.7325)"
sample5 = "tensor(0.7082) tensor(0.7242) tensor(0.7182) tensor(0.6789) tensor(0.6830) tensor(0.7045) tensor(0.7020) tensor(0.6929) tensor(0.7188) tensor(0.6783) tensor(0.7197) tensor(0.7034) tensor(0.6957) tensor(0.7124) tensor(0.7074) tensor(0.7009) tensor(0.7009) tensor(0.6973) tensor(0.7068) tensor(0.6872)"
sample6 = "tensor(0.6882) tensor(0.7127) tensor(0.6937) tensor(0.6841) tensor(0.6803) tensor(0.6870) tensor(0.6999) tensor(0.6918) tensor(0.6951) tensor(0.7052) tensor(0.7066) tensor(0.7029) tensor(0.6979) tensor(0.7015) tensor(0.6748) tensor(0.6924) tensor(0.6906) tensor(0.6965) tensor(0.7082) tensor(0.7047)"
sample7 = "tensor(0.6954) tensor(0.6903) tensor(0.7216) tensor(0.7172) tensor(0.7086) tensor(0.7349) tensor(0.6610) tensor(0.7022) tensor(0.7379) tensor(0.6896) tensor(0.6421) tensor(0.7185) tensor(0.7121) tensor(0.6983) tensor(0.6921) tensor(0.6942) tensor(0.7032) tensor(0.7172) tensor(0.7317) tensor(0.6990)"
sample8 = "tensor(0.7090) tensor(0.7148) tensor(0.7104) tensor(0.7193) tensor(0.6960) tensor(0.7185) tensor(0.7216) tensor(0.7119) tensor(0.7076) tensor(0.7124) tensor(0.7338) tensor(0.6952) tensor(0.7175) tensor(0.6889) tensor(0.7057) tensor(0.7277) tensor(0.7143) tensor(0.7093) tensor(0.7181) tensor(0.7108)"

# %%
samples = [sample0, sample1, sample2, sample3, sample4, sample5, sample6, sample7, sample8]
for i in range(len(samples)):
  samples[i] = samples[i].replace("tensor(", '')
  samples[i] = samples[i].replace(')', '')
  samples[i] = [float(j) for j in samples[i].split(" ")]

# %%
plt.figure(figsize = (16., 6.))
#activation_functions = [torch.nn.ELU, torch.nn.LeakyReLU, torch.nn.PReLU, torch.nn.ReLU, torch.nn.ReLU6, torch.nn.SELU, torch.nn.CELU, torch.nn.GELU, torch.nn.Tanh, torch.nn.GLU]
plt.boxplot(samples, labels = ['elu', 'leakyrely', 'prelu', 'relu', 'relu6', 'selu', 'celu', 'gelu', 'tanh'])
plt.show()

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.44981092695369296

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[2])
p_val
# Out:
# 2.1535865470396194e-07

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[3])
p_val
# Out:
# 0.045668276139277916

# %%
t_stat, p_val = stats.ttest_ind(samples[3], samples[4])
p_val
# Out:
# 1.0472421506980766e-06

# %%
t_stat, p_val = stats.ttest_ind(samples[4], samples[5])
p_val
# Out:
# 6.434951975808969e-08

# %%
t_stat, p_val = stats.ttest_ind(samples[4], samples[6])
p_val
# Out:
# 5.747170416745968e-11

# %%
t_stat, p_val = stats.ttest_ind(samples[4], samples[7])
p_val
# Out:
# 3.60075039409366e-05

# %%
t_stat, p_val = stats.ttest_ind(samples[4], samples[8])
p_val
# Out:
# 1.9669387256184938e-05
