# %% [markdown]
# <a href="https://colab.research.google.com/github/KORALLLL/MTUCI_EMNIST/blob/Kirill/notebooks/week2/ResearchOfDifferentConvLayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Models

# %% [markdown]
# First model
#
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>5*5</th>
#     <th>1</th>
#     <th>2</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>5*5</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Second model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Third model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Fourth model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Fifth model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# sixth model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# # Hyperparameters

# %% [markdown]
# train dataset: MNIST + EMNIST letters
#
# test dataset: dataset of DreamTeam
#
# training sample size: 36960 * 2
#
# validation sample size: 30800
#
# testing sample size: 16784
#
# loss finction: Cross Entropy Loss
#
# optimizer: adam
#
# learning rate: 0.001
#
# batch size: 1120
#
# epoch number: 65, 80, 100, 120, 150, 100

# %% [markdown]
# # Module importation

# %%
import torch
import torchvision.datasets
import torchvision.transforms as transforms
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as bar
import pickle
import numpy as np
import scipy.stats as stats

# %% [markdown]
# # Git cloning

# %%
# !git clone https://github.com/KORALLLL/MTUCI_EMNIST.git
# Out:
# Cloning into 'MTUCI_EMNIST'...
# remote: Enumerating objects: 36432, done.
# remote: Counting objects: 100% (12792/12792), done.
# remote: Compressing objects: 100% (12675/12675), done.
# remote: Total 36432 (delta 148), reused 12689 (delta 112), pack-reused 23640
# Receiving objects: 100% (36432/36432), 128.29 MiB | 30.74 MiB/s, done.
# Resolving deltas: 100% (433/433), done.

# %% [markdown]
# # Dataset preparation

# %%
emnist_train = torchvision.datasets.EMNIST('./', split='letters', download = True, train = True)
mnist_train = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = True)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

emnist_train_data = emnist_train.data
mnist_train_data = mnist_train.data
train_data = torch.cat([emnist_train_data[:49920], mnist_train_data[:24000]], dim=0).float().unsqueeze(1).to(device) / 255

temp_emnist_train_labels = emnist_train.targets[:49920]
emnist_train_labels = []

for i in range(len(temp_emnist_train_labels)):
  if temp_emnist_train_labels[i]==15:
    emnist_train_labels.append(torch.tensor(0))
  elif temp_emnist_train_labels[i]>15:
    emnist_train_labels.append(temp_emnist_train_labels[i]+8)
  else:
    emnist_train_labels.append(temp_emnist_train_labels[i]+9)

mnist_train_labels = mnist_train.targets
train_labels = torch.cat([torch.stack(emnist_train_labels[:49920]), mnist_train_labels[:24000]], dim=0).to(device)

file = open('MTUCI_EMNIST/dataset.pkl', 'rb')
test_dataset = pickle.load(file)
file.close()

test_data = test_dataset['data'].numpy()
test_data = np.flip(test_data, axis = 3)
test_data = np.rot90(test_data, k=1, axes=(2,3))
test_data = 1 - test_data
test_data = torch.from_numpy(test_data).float().to(device)
test_labels = test_dataset['targets'].to(device)
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to ./EMNIST/raw/gzip.zip
# 100%|██████████| 561753746/561753746 [00:10<00:00, 54044934.41it/s]
# Extracting ./EMNIST/raw/gzip.zip to ./EMNIST/raw

# %% [markdown]
# # Confugiration nets

# %%
class Lenet1(torch.nn.Module):
  def __init__(self):
    super(Lenet1, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 6, kernel_size=5, padding = 2)
    self.act1 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride = 2)
    self.act2 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0)
    self.act3 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride = 2)
    self.act4 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(5*5*16, 120)
    self.act5 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act6 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.pool1(x)
    x = self.act2(x)
    x = self.conv2(x)
    x = self.act3(x)
    x = self.pool2(x)
    x = self.act4(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act5(x)
    x = self.fc2(x)
    x = self.act6(x)
    x = self.fc3(x)
    return x

# %%
class Lenet2(torch.nn.Module):
  def __init__(self):
    super(Lenet2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act3 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act4 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act5 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act6 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(5*5*16, 120)
    self.act7 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act8 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.pool1(x)
    x = self.act3(x)
    x = self.conv3(x)
    x = self.act4(x)
    x = self.conv4(x)
    x = self.act5(x)
    x = self.pool2(x)
    x = self.act6(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act7(x)
    x = self.fc2(x)
    x = self.act8(x)
    x = self.fc3(x)
    return x

# %%
class Lenet3(torch.nn.Module):
  def __init__(self):
    super(Lenet3, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act4 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act7 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act8 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(5*5*16, 120)
    self.act9 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120,84)
    self.act10 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.pool1(x)
    x = self.act4(x)
    x = self.conv4(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.pool2(x)
    x = self.act8(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act9(x)
    x = self.fc2(x)
    x = self.act10(x)
    x = self.fc3(x)
    return x

# %%
class Lenet4(torch.nn.Module):
  def __init__(self):
    super(Lenet4, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act10 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act11 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.pool1(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.pool2(x)
    x = self.act10(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)
    return x

# %%
class Lenet5(torch.nn.Module):
  def __init__(self):
    super(Lenet5,self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act11 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act12 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act13 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act14 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self,x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.pool1(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.pool2(x)
    x = self.act12(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act13(x)
    x = self.fc2(x)
    x = self.act14(x)
    x = self.fc3(x)
    return x

# %%
class Lenet6(torch.nn.Module):
  def __init__(self):
    super(Lenet6, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = self.pool1(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %% [markdown]
# # Test train

# %% [markdown]
# ## 1net

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet1().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
batch_size = 1120

for epoch in bar(range(100), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
# Out:
# <ipython-input-17-83f70d59f890>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(100), desc='learning'):
# learning:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)
plt.xlim(50,80)
plt.ylim(0.66, 0.7)
# Out:
# (0.66, 0.7)

# %% [markdown]
# ## Net2

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet2().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
batch_size = 1120

for epoch in bar(range(300), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
# Out:
# <ipython-input-25-4fd5a403cf0f>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(300), desc='learning'):
# learning:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)
plt.xlim(40,120)
plt.ylim(0.65, 0.7)
# Out:
# (0.65, 0.7)

# %% [markdown]
# ## Net3

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet3().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120

for epoch in bar(range(300), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-42-e478920b07f8>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(300), desc='learning'):
# learning:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_loss_history)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)
plt.xlim(50,300)
plt.ylim(0.63, 0.68)
# Out:
# (0.63, 0.68)

# %% [markdown]
# ## net 4

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet4().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120

for epoch in bar(range(300), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-56-2b137c48f4ed>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(300), desc='learning'):
# learning:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)
plt.ylim(0.68, 0.73)
plt.xlim(, 300)
# Out:
# (40.0, 300.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_loss_history)

# %% [markdown]
# ## net5

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet5().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120

for epoch in bar(range(300), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-64-a2e0a7cf273b>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(300), desc='learning'):
# learning:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 300)
# Out:
# (30.0, 300.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_loss_history)

# %% [markdown]
# #net6

# %%
loss = torch.nn.CrossEntropyLoss()
lenet = Lenet6().to(device)
optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120

for epoch in bar(range(300), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-89-7ca5add35450>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(300), desc='learning'):
# learning:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 300)
# Out:
# (30.0, 300.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(300), test_loss_history)

# %% [markdown]
# # Investigation

# %%
nets = [Lenet1, Lenet2, Lenet3, Lenet4, Lenet5, Lenet6]
epoches = [65, 80, 100, 120, 150, 100]

for net in bar(range(6), desc = 'nets'):
  accuracy_net = []
  for experiment in bar(range(20), desc = 'sample eperimnet'):

    loss = torch.nn.CrossEntropyLoss()
    lenet = nets[net]().to(device)
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(epoches[net]):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()

    test_preds = lenet.forward(test_data)
    accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
    accuracy_net.append(accuracy)
  print(f'accuracy of {net} net:')
  print(*accuracy_net)
# Out:
# <ipython-input-22-fbb1efc264e8>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for net in bar(range(6), desc = 'nets'):
# nets:   0%|          | 0/6 [00:00<?, ?it/s]
# <ipython-input-22-fbb1efc264e8>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(20), desc = 'sample eperimnet'):
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# accuracy of 0 net:
# tensor(0.7412) tensor(0.7185) tensor(0.7281) tensor(0.7223) tensor(0.7151) tensor(0.7301) tensor(0.7114) tensor(0.7199) tensor(0.7195) tensor(0.7149) tensor(0.7208) tensor(0.7181) tensor(0.7408) tensor(0.7122) tensor(0.7138) tensor(0.7252) tensor(0.7429) tensor(0.7360) tensor(0.7122) tensor(0.7204)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# accuracy of 1 net:
# tensor(0.7153) tensor(0.7230) tensor(0.6876) tensor(0.6956) tensor(0.7058) tensor(0.7059) tensor(0.7240) tensor(0.7027) tensor(0.7231) tensor(0.7009) tensor(0.7102) tensor(0.6988) tensor(0.6440) tensor(0.7256) tensor(0.7001) tensor(0.7124) tensor(0.7017) tensor(0.7081) tensor(0.6948) tensor(0.7168)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# accuracy of 2 net:
# tensor(0.7035) tensor(0.6901) tensor(0.7276) tensor(0.7255) tensor(0.7295) tensor(0.7344) tensor(0.7168) tensor(0.7314) tensor(0.7387) tensor(0.7401) tensor(0.7260) tensor(0.7246) tensor(0.7181) tensor(0.7049) tensor(0.7326) tensor(0.7174) tensor(0.7152) tensor(0.7240) tensor(0.7233) tensor(0.7188)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# accuracy of 3 net:
# tensor(0.7336) tensor(0.7291) tensor(0.7187) tensor(0.7378) tensor(0.6402) tensor(0.7288) tensor(0.6919) tensor(0.7364) tensor(0.7393) tensor(0.7353) tensor(0.7244) tensor(0.7369) tensor(0.7214) tensor(0.7089) tensor(0.7154) tensor(0.7421) tensor(0.7281) tensor(0.7541) tensor(0.7219) tensor(0.7280)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# accuracy of 4 net:
# tensor(0.7221) tensor(0.7129) tensor(0.7031) tensor(0.7373) tensor(0.7188) tensor(0.7216) tensor(0.7378) tensor(0.7160) tensor(0.7292) tensor(0.7431) tensor(0.7492) tensor(0.7367) tensor(0.7397) tensor(0.7359) tensor(0.7459) tensor(0.7158) tensor(0.7280) tensor(0.7058) tensor(0.7263) tensor(0.0499)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-fbb1efc264e8> in <cell line: 4>()
#      25
#      26         loss_val = loss(preds, labels_batch)
# ---> 27         loss_val.backward()
#      28
#      29         optimizer.step()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
#   <matplotlib.lines.Line2D at 0x797b3a88ab30>,
#   <matplotlib.lines.Line2D at 0x797b3a88b6d0>,
#   <matplotlib.lines.Line2D at 0x797b3a888fa0>,
#   <matplotlib.lines.Line2D at 0x797b3a8895a0>,
#   <matplotlib.lines.Line2D at 0x797b3a88acb0>,
#   <matplotlib.lines.Line2D at 0x797b3a76d240>,
#   <matplotlib.lines.Line2D at 0x797b3a76dff0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x797b3a7111e0>,
#   <matplotlib.lines.Line2D at 0x797b3a712920>,
#   <matplotlib.lines.Line2D at 0x797b3a889900>,
#   <matplotlib.lines.Line2D at 0x797b3a88bd60>,
#   <matplotlib.lines.Line2D at 0x797b3a8893c0>,
#   <matplotlib.lines.Line2D at 0x797b3a888310>],
#  'medians': [<matplotlib.lines.Line2D at 0x797b3a710880>,
#   <matplotlib.lines.Line2D at 0x797b3a889ae0>,
#   <matplotlib.lines.Line2D at 0x797b3a889e10>,
#   <matplotlib.lines.Line2D at 0x797b3a888190>,
#   <matplotlib.lines.Line2D at 0x797b3a88aaa0>,
#   <matplotlib.lines.Line2D at 0x797b3a76dc00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x797b3a7102b0>,
#   <matplotlib.lines.Line2D at 0x797b3a889540>,
#   <matplotlib.lines.Line2D at 0x797b3a88b9a0>,
#   <matplotlib.lines.Line2D at 0x797b3a889a80>,
#   <matplotlib.lines.Line2D at 0x797b3a888820>,
#   <matplotlib.lines.Line2D at 0x797b3a76d7b0>],
#  'means': []}

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.00029116964380905097

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[2])
p_val
# Out:
# 0.7706529053172279

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[3])
p_val
# Out:
# 0.9388639264727066

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[4])
p_val
# Out:
# 0.2466768881080764

# %%
import scipy.stats as stats
t_stat, p_val = stats.ttest_ind(samples[0], samples[5])
p_val
# Out:
# 0.09347518358120697

# %% [markdown]
# ## research of different pooling layers

# %% [markdown]
# ## net1

# %% [markdown]
# first model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# second model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>maximum pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# third model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>maximum pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# fourth model
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>maximum pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convoluation</th>
#     <th>11</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>maximum pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>relu</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# # Module importation

# %%
import torch
import torchvision.datasets
import torchvision.transforms as transforms
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as bar
import pickle
import numpy as np

# %% [markdown]
# # Git cloning

# %%
# !git clone https://github.com/KORALLLL/MTUCI_EMNIST.git -b main
# Out:
# Cloning into 'MTUCI_EMNIST'...
# remote: Enumerating objects: 36432, done.
# remote: Counting objects: 100% (12792/12792), done.
# remote: Compressing objects: 100% (12675/12675), done.
# remote: Total 36432 (delta 148), reused 12689 (delta 112), pack-reused 23640
# Receiving objects: 100% (36432/36432), 128.29 MiB | 16.27 MiB/s, done.
# Resolving deltas: 100% (433/433), done.

# %% [markdown]
# # Dataset preparation

# %%
emnist_train = torchvision.datasets.EMNIST('./', split='letters', download = True, train = True)
mnist_train = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = True)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

emnist_train_data = emnist_train.data
mnist_train_data = mnist_train.data
train_data = torch.cat([emnist_train_data[:49920], mnist_train_data[:24000]], dim=0).float().unsqueeze(1).to(device) / 255

temp_emnist_train_labels = emnist_train.targets[:49920]
emnist_train_labels = []

for i in range(len(temp_emnist_train_labels)):
  if temp_emnist_train_labels[i]==15:
    emnist_train_labels.append(torch.tensor(0))
  elif temp_emnist_train_labels[i]>15:
    emnist_train_labels.append(temp_emnist_train_labels[i]+8)
  else:
    emnist_train_labels.append(temp_emnist_train_labels[i]+9)

mnist_train_labels = mnist_train.targets
train_labels = torch.cat([torch.stack(emnist_train_labels[:49920]), mnist_train_labels[:24000]], dim=0).to(device)

file = open('MTUCI_EMNIST/dataset.pkl', 'rb')
test_dataset = pickle.load(file)
file.close()

test_data = test_dataset['data'].numpy()
test_data = np.flip(test_data, axis = 3)
test_data = np.rot90(test_data, k=1, axes=(2,3))
test_data = 1 - test_data
test_data = torch.from_numpy(test_data).float().to(device)
test_labels = test_dataset['targets'].to(device)
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to ./EMNIST/raw/gzip.zip
# 100%|██████████| 561753746/561753746 [00:52<00:00, 10749368.51it/s]
# Extracting ./EMNIST/raw/gzip.zip to ./EMNIST/raw

# %% [markdown]
# # configuration nets

# %%
class Lenet1(torch.nn.Module):
  def __init__(self):
    super(Lenet1, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = self.pool1(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %%
class Lenet2(torch.nn.Module):
  def __init__(self):
    super(Lenet2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = self.pool1(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %%
class Lenet3(torch.nn.Module):
  def __init__(self):
    super(Lenet3, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = self.pool1(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %%
class Lenet4(torch.nn.Module):
  def __init__(self):
    super(Lenet4, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=3, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=6, out_channels=6, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=6, out_channels=11, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=11, out_channels=11, kernel_size=3, padding=1)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=11, out_channels=16, kernel_size=3, padding=0)
    self.act11 = torch.nn.ReLU()
    self.conv11 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act12 = torch.nn.ReLU()
    self.conv12 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act13 = torch.nn.ReLU()
    self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act14 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act15 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)
    x = self.pool1(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)
    x = self.pool2(x)
    x = self.act14(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)
    return x

# %% [markdown]
# # investigation

# %%
nets = [Lenet1, Lenet2, Lenet3, Lenet4]

for net in bar(range(4), desc = 'nets'):
  accuracy_net = []
  for experiment in bar(range(20), desc = 'sample eperimnet'):

    loss = torch.nn.CrossEntropyLoss()
    lenet = nets[net]().to(device)
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(100):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()

    test_preds = lenet.forward(test_data)
    accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
    accuracy_net.append(accuracy)
  print(f'accuracy of {net} net:')
  print(*accuracy_net)
# Out:
# <ipython-input-16-d8b4c40870cd>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for net in bar(range(4), desc = 'nets'):
# nets:   0%|          | 0/4 [00:00<?, ?it/s]
# <ipython-input-16-d8b4c40870cd>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(20), desc = 'sample eperimnet'):
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# accuracy of 0 net:
# tensor(0.7348) tensor(0.7587) tensor(0.7353) tensor(0.7419) tensor(0.7524) tensor(0.6702) tensor(0.6951) tensor(0.0499) tensor(0.7188) tensor(0.7592) tensor(0.7506) tensor(0.6446) tensor(0.7527) tensor(0.7462) tensor(0.7207) tensor(0.7542) tensor(0.7309) tensor(0.7088) tensor(0.0499) tensor(0.7562)
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d8b4c40870cd> in <cell line: 3>()
#      21         labels_batch= train_labels[batch_indexes]
#      22
# ---> 23         preds = lenet.forward(data_batch)
#      24
#      25         loss_val = loss(preds, labels_batch)
#
# <ipython-input-12-5c2c602f1110> in forward(self, x)
#      36     self.fc3 = torch.nn.Linear(84, 35)
#      37
# ---> 38   def forward(self, x):
#      39     x = self.conv1(x)
#      40     x = self.act1(x)
#
# KeyboardInterrupt:

# %% [markdown]
# net1
# tensor(0.7348) tensor(0.7587) tensor(0.7353) tensor(0.7419) tensor(0.7524) tensor(0.6702) tensor(0.6951) tensor(0.0499) tensor(0.7188) tensor(0.7592) tensor(0.7506) tensor(0.6446) tensor(0.7527) tensor(0.7462) tensor(0.7207) tensor(0.7542) tensor(0.7309) tensor(0.7088) tensor(0.0499) tensor(0.7562)

# %%
nets = [Lenet1, Lenet2, Lenet3, Lenet4]

for net in bar(range(3,4), desc = 'nets'):
  accuracy_net = []
  for experiment in bar(range(20), desc = 'sample eperimnet'):

    loss = torch.nn.CrossEntropyLoss()
    lenet = nets[net]().to(device)
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(100):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()

    test_preds = lenet.forward(test_data)
    accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
    print(accuracy)
    accuracy_net.append(accuracy)
  print(f'accuracy of {net} net:')
  print(*accuracy_net)
# Out:
# <ipython-input-9-29bb9530092b>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for net in bar(range(3,4), desc = 'nets'):
# nets:   0%|          | 0/1 [00:00<?, ?it/s]
# <ipython-input-9-29bb9530092b>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(20), desc = 'sample eperimnet'):
# sample eperimnet:   0%|          | 0/20 [00:00<?, ?it/s]
# tensor(0.7190)
# tensor(0.7300)
# tensor(0.0499)
# tensor(0.7463)
# tensor(0.7487)
# tensor(0.7451)
# tensor(0.7344)
# tensor(0.0499)
# tensor(0.7294)
# tensor(0.7221)
# tensor(0.7269)
# tensor(0.7359)
# tensor(0.7224)
# tensor(0.7410)
# tensor(0.7298)
# tensor(0.7350)
# tensor(0.7330)
# tensor(0.7042)
# tensor(0.7328)
# tensor(0.0499)
# accuracy of 3 net:
# tensor(0.7190) tensor(0.7300) tensor(0.0499) tensor(0.7463) tensor(0.7487) tensor(0.7451) tensor(0.7344) tensor(0.0499) tensor(0.7294) tensor(0.7221) tensor(0.7269) tensor(0.7359) tensor(0.7224) tensor(0.7410) tensor(0.7298) tensor(0.7350) tensor(0.7330) tensor(0.7042) tensor(0.7328) tensor(0.0499)

# %% [markdown]
# net 2
# tensor(0.7312)
# tensor(0.7327)
# tensor(0.7472)
# tensor(0.6893)
# tensor(0.7247)
# tensor(0.7147)
# tensor(0.0499)
# tensor(0.7341)
# tensor(0.7220)
# tensor(0.7414)
# tensor(0.7271)
# tensor(0.7094)
# tensor(0.7328)
# tensor(0.0499)
# tensor(0.7403)
# tensor(0.7032)
# tensor(0.7468)
# tensor(0.7436)
# tensor(0.7185)
# tensor(0.7327)
#
# net3
# tensor(0.0499)
# tensor(0.7313)
# tensor(0.0499)
# tensor(0.7280)
# tensor(0.7397)
# tensor(0.7454)
# tensor(0.0499)
# tensor(0.6998)
# tensor(0.7438)
# tensor(0.7300)
# tensor(0.7093)
# tensor(0.7532)
# tensor(0.0499)
# tensor(0.7523)
# tensor(0.0499)
# tensor(0.0499)
# tensor(0.7308)
# tensor(0.0499)
# tensor(0.7508)
# tensor(0.7072)
# tensor(0.7372)
# tensor(0.7388)
# tensor(0.7483)
#
# net4
# tensor(0.7190)
# tensor(0.7300)
# tensor(0.0499)
# tensor(0.7463)
# tensor(0.7487)
# tensor(0.7451)
# tensor(0.7344)
# tensor(0.0499)
# tensor(0.7294)
# tensor(0.7221)
# tensor(0.7269)
# tensor(0.7359)
# tensor(0.7224)
# tensor(0.7410)
# tensor(0.7298)
# tensor(0.7350)
# tensor(0.7330)
# tensor(0.7042)
# tensor(0.7328)
# tensor(0.0499)

# %%
sample1 = "tensor(0.7348) tensor(0.7587) tensor(0.7353) tensor(0.7419) tensor(0.7524) tensor(0.6702) tensor(0.6951) tensor(0.0499) tensor(0.7188) tensor(0.7592) tensor(0.7506) tensor(0.6446) tensor(0.7527) tensor(0.7462) tensor(0.7207) tensor(0.7542) tensor(0.7309) tensor(0.7088) tensor(0.0499) tensor(0.7562)"
sample2 = "tensor(0.7312) tensor(0.7327) tensor(0.7472) tensor(0.6893) tensor(0.7247) tensor(0.7147) tensor(0.0499) tensor(0.7341) tensor(0.7220) tensor(0.7414) tensor(0.7271) tensor(0.7094) tensor(0.7328) tensor(0.0499) tensor(0.7403) tensor(0.7032) tensor(0.7468) tensor(0.7436) tensor(0.7185) tensor(0.7327)"
sample3 = "tensor(0.0499) tensor(0.7313) tensor(0.0499) tensor(0.7280) tensor(0.7397) tensor(0.7454) tensor(0.0499) tensor(0.6998) tensor(0.7438) tensor(0.7300) tensor(0.7093) tensor(0.7532) tensor(0.0499) tensor(0.7523) tensor(0.0499) tensor(0.0499) tensor(0.7308) tensor(0.0499) tensor(0.7508) tensor(0.7072) tensor(0.7372) tensor(0.7388) tensor(0.7483)"
sample4 = "tensor(0.7190) tensor(0.7300) tensor(0.0499) tensor(0.7463) tensor(0.7487) tensor(0.7451) tensor(0.7344) tensor(0.0499) tensor(0.7294) tensor(0.7221) tensor(0.7269) tensor(0.7359) tensor(0.7224) tensor(0.7410) tensor(0.7298) tensor(0.7350) tensor(0.7330) tensor(0.7042) tensor(0.7328) tensor(0.0499)"

# %%
samples = [sample1, sample2, sample3, sample4]
for i in range(len(samples)):
  samples[i] = samples[i].replace("tensor(", '')
  samples[i] = samples[i].replace(')', '')
  samples[i] = [float(j) for j in samples[i].split(" ")]

# %%
plt.figure(figsize = (16., 6.))
plt.boxplot(samples)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bd15a297dc0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa00a0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa1090>,
#   <matplotlib.lines.Line2D at 0x7bd159fa1330>,
#   <matplotlib.lines.Line2D at 0x7bd159fa22f0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa2590>,
#   <matplotlib.lines.Line2D at 0x7bd159fa3550>,
#   <matplotlib.lines.Line2D at 0x7bd159fa37f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bd159fa0340>,
#   <matplotlib.lines.Line2D at 0x7bd159fa05e0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa15d0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa1870>,
#   <matplotlib.lines.Line2D at 0x7bd159fa2830>,
#   <matplotlib.lines.Line2D at 0x7bd159fa2ad0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa3a90>,
#   <matplotlib.lines.Line2D at 0x7bd159fa3d30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7bd15a297b20>,
#   <matplotlib.lines.Line2D at 0x7bd159fa0df0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa2050>,
#   <matplotlib.lines.Line2D at 0x7bd159fa32b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bd159fa0880>,
#   <matplotlib.lines.Line2D at 0x7bd159fa1b10>,
#   <matplotlib.lines.Line2D at 0x7bd159fa2d70>,
#   <matplotlib.lines.Line2D at 0x7bd159fa3fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bd159fa0b20>,
#   <matplotlib.lines.Line2D at 0x7bd159fa1db0>,
#   <matplotlib.lines.Line2D at 0x7bd159fa3010>,
#   <matplotlib.lines.Line2D at 0x7bd159fdc2b0>],
#  'means': []}

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[3])
p_val
# Out:
# 0.8082413151530026
