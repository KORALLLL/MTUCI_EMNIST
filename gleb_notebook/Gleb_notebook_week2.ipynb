# %% [markdown]
# <a href="https://colab.research.google.com/github/KORALLLL/MTUCI_EMNIST/blob/Gleb/gleb_notebook/Gleb_notebook_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>5*5</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>5*5</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>10</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>10</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>10</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>10</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>10</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>10</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#    </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>average pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>10</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>10</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>10</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>10</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th>layer</th>
#     <th>layer type2</th>
#     <th>feature maps</th>
#     <th>size</th>
#     <th>kernel size</th>
#     <th>stride</th>
#     <th>padding</th>
#     <th>activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>3</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>26*26</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>6</th>
#     <th>26*26</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>9</th>
#     <th>24*24</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   </tr>
#     <tr>
#     <th>1</th>
#     <th>convoluation</th>
#     <th>9</th>
#     <th>24*24</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>average pooling</th>
#     <th>9</th>
#     <th>12*12</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>12</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>12</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>0</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convoluation</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>average pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>10</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# train dataset: MNIST + EMNIST letters
#
# test dataset: dataset of DreamTeam
#
# training sample size: 36960
#
# testing sample size: 16784
#
# loss finction: Cross Entropy Loss
#
# optimizer: adam
#
# learning rate: 0.001
#
# batch size: 560
#
# epoch number: 100

# %%
import torch
import torchvision.datasets
import torchvision.transforms as transforms
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as bar
import pickle
import numpy as np
import scipy.stats as stats

# %%
# !git clone https://github.com/KORALLLL/MTUCI_EMNIST.git
# Out:
# Cloning into 'MTUCI_EMNIST'...
# remote: Enumerating objects: 36449, done.
# remote: Counting objects: 100% (12809/12809), done.
# remote: Compressing objects: 100% (12692/12692), done.
# remote: Total 36449 (delta 157), reused 12688 (delta 112), pack-reused 23640
# Receiving objects: 100% (36449/36449), 128.44 MiB | 31.26 MiB/s, done.
# Resolving deltas: 100% (442/442), done.

# %%
emnist_train = torchvision.datasets.EMNIST('./', split='letters', download = True, train = True)
mnist_train = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = True)
emnist_val = torchvision.datasets.EMNIST('./', split='letters', download = True, train = False)
mnist_val = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = False)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

emnist_train_data = emnist_train.data
mnist_train_data = mnist_train.data
train_data = torch.cat([emnist_train_data[:24960], mnist_train_data[:12000]], dim=0).float().unsqueeze(1).to(device) / 255

emnist_val_data = emnist_val.data
mnist_val_data = mnist_val.data
val_data = torch.cat([emnist_val_data, mnist_val_data], dim=0).float().unsqueeze(1).to(device) / 255

temp_emnist_train_labels = emnist_train.targets[:24960]
emnist_train_labels = []

temp_emnist_val_labels = emnist_val.targets
emnist_val_labels = []

for i in range(len(temp_emnist_train_labels)):
  if temp_emnist_train_labels[i]==15:
    emnist_train_labels.append(torch.tensor(0))
  elif temp_emnist_train_labels[i]>15:
    emnist_train_labels.append(temp_emnist_train_labels[i]+8)
  else:
    emnist_train_labels.append(temp_emnist_train_labels[i]+9)

for i in range(len(temp_emnist_val_labels)):
  if temp_emnist_val_labels[i]==15:
    emnist_val_labels.append(torch.tensor(0))
  elif temp_emnist_val_labels[i]>15:
    emnist_val_labels.append(temp_emnist_val_labels[i] + 8)
  else:
    emnist_val_labels.append(temp_emnist_val_labels[i]+9)

mnist_train_labels = mnist_train.targets
train_labels = torch.cat([torch.stack(emnist_train_labels[:24960]), mnist_train_labels[:12000]], dim=0).to(device)

mnist_val_labels = mnist_val.targets
val_labels = torch.cat([torch.stack(emnist_val_labels), mnist_val_labels], dim=0).to(device)


file = open('MTUCI_EMNIST/dataset.pkl', 'rb')
test_dataset = pickle.load(file)
file.close()

test_data = test_dataset['data'].numpy()
test_data = np.flip(test_data, axis = 3)
test_data = np.rot90(test_data, k=1, axes=(2,3))
test_data = 1 - test_data
test_data = torch.from_numpy(test_data).float().to(device)
test_labels = test_dataset['targets'].to(device)
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to ./EMNIST/raw/gzip.zip
# 100%|██████████| 561753746/561753746 [00:12<00:00, 46376069.49it/s]
# Extracting ./EMNIST/raw/gzip.zip to ./EMNIST/raw

# %%
plt.imshow(val_data[0][0].cpu())

# %%
class LeNet1(torch.nn.Module):
  def __init__(self):
    super(LeNet1, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 6, kernel_size = 5, padding = 2)
    self.act1 = torch.nn.Tanh()
    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act2 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 6, out_channels = 16, kernel_size = 5, padding = 0)
    self.act3 = torch.nn.Tanh()
    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act4 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act5 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act6 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.pool1(x)
    x = self.act2(x)
    x = self.conv2(x)
    x = self.act3(x)
    x = self.pool2(x)
    x = self.act4(x)
    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act5(x)
    x = self.fc2(x)
    x = self.act6(x)
    x = self.fc3(x)

    return x

# %%
class LeNet2(torch.nn.Module):
  def __init__(self):
    super(LeNet2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 1)
    self.act2 = torch.nn.Tanh()
    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act3 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 6, out_channels = 10, kernel_size = 3, padding = 0)
    self.act4 = torch.nn.Tanh()
    self.conv4 = torch.nn.Conv2d(in_channels = 10, out_channels = 16, kernel_size = 3, padding = 0)
    self.act5 = torch.nn.Tanh()
    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act6 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act7 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act8 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.pool1(x)
    x = self.act3(x)
    x = self.conv3(x)
    x = self.act4(x)
    x = self.conv4(x)
    x = self.act5(x)
    x = self.pool2(x)
    x = self.act6(x)
    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act7(x)
    x = self.fc2(x)
    x = self.act8(x)
    x = self.fc3(x)

    return x

# %%
class LeNet3(torch.nn.Module):
  def __init__(self):
    super(LeNet3, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 3, kernel_size = 3, padding = 1)
    self.act2 = torch.nn.Tanh()

    self.conv3 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()
    self.conv4 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act4 = torch.nn.Tanh()

    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act5 = torch.nn.Tanh()

    self.conv5 = torch.nn.Conv2d(in_channels = 6, out_channels = 10, kernel_size = 3, padding = 0)
    self.act6 = torch.nn.Tanh()
    self.conv6 = torch.nn.Conv2d(in_channels = 10, out_channels = 10, kernel_size = 3, padding = 1)
    self.act7 = torch.nn.Tanh()

    self.conv7 = torch.nn.Conv2d(in_channels = 10, out_channels = 16, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()
    self.conv8 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()

    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act10 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act11 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)

    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)

    x = self.pool1(x)
    x = self.act5(x)

    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)

    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)

    x = self.pool2(x)
    x = self.act10(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)

    return x

# %%
class LeNet4(torch.nn.Module):
  def __init__(self):
    super(LeNet4, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 3, kernel_size = 3, padding = 1)
    self.act2 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 3, out_channels = 3, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()

    self.conv4 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 1)
    self.act4 = torch.nn.Tanh()
    self.conv5 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act5 = torch.nn.Tanh()
    self.conv6 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act6 = torch.nn.Tanh()

    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act7 = torch.nn.Tanh()

    self.conv7 = torch.nn.Conv2d(in_channels = 6, out_channels = 10, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()
    self.conv8 = torch.nn.Conv2d(in_channels = 10, out_channels = 10, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()
    self.conv9 = torch.nn.Conv2d(in_channels = 10, out_channels = 10, kernel_size = 3, padding = 1)
    self.act10 = torch.nn.Tanh()

    self.conv10 = torch.nn.Conv2d(in_channels = 10, out_channels = 16, kernel_size = 3, padding = 0)
    self.act11 = torch.nn.Tanh()
    self.conv11 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act12 = torch.nn.Tanh()
    self.conv12 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act13 = torch.nn.Tanh()

    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act14 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act15 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act16 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)

    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.conv6(x)
    x = self.act6(x)

    x = self.pool1(x)
    x = self.act7(x)

    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)

    x = self.conv10(x)
    x = self.act11(x)
    x = self.conv11(x)
    x = self.act12(x)
    x = self.conv12(x)
    x = self.act13(x)

    x = self.pool2(x)
    x = self.act14(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act15(x)
    x = self.fc2(x)
    x = self.act16(x)
    x = self.fc3(x)

    return x

# %%
class LeNet5(torch.nn.Module):
  def __init__(self):
    super(LeNet5, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 0)
    self.act2 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()

    self.conv4 = torch.nn.Conv2d(in_channels = 6, out_channels = 9, kernel_size = 3, padding = 0)
    self.act4 = torch.nn.Tanh()
    self.conv5 = torch.nn.Conv2d(in_channels = 9, out_channels = 9, kernel_size = 3, padding = 1)
    self.act5 = torch.nn.Tanh()

    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act6 = torch.nn.Tanh()

    self.conv6 = torch.nn.Conv2d(in_channels = 9, out_channels = 12, kernel_size = 3, padding = 1)
    self.act7 = torch.nn.Tanh()
    self.conv7 = torch.nn.Conv2d(in_channels = 12, out_channels = 16, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()

    self.conv8 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()
    self.conv9 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act10 = torch.nn.Tanh()

    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act11 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act12 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act13 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)

    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)

    x = self.pool1(x)
    x = self.act6(x)

    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)

    x = self.pool2(x)
    x = self.act11(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act12(x)
    x = self.fc2(x)
    x = self.act13(x)
    x = self.fc3(x)

    return x

# %%
batch_size = 560
lenet = LeNet1().to(device)
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
test_accuracy = []
test_loss = []
for epoch in bar(range(50), desc = 'learning'):
  indexs = np.random.permutation(len(train_data))
  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()
    batch_index = indexs[start_index: start_index + batch_size]
    labels_batch = train_labels[batch_index].to(device)

    images_batch = train_data[batch_index].to(device)
    prediction = lenet.forward(images_batch)
    loss_value = loss(prediction, labels_batch)
    loss_value.backward()
    optimizer.step()

  prediction_test = lenet.forward(test_data)
  test_loss.append(loss(prediction_test, test_labels).data.cpu())

  test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

  test_accuracy.append(test_acc)
# Out:
# <ipython-input-15-681d8285c1b5>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(50), desc = 'learning'):
# learning:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.figure(figsize= (16.0, 6.0))
plt.plot(range(50), test_accuracy, c = 'red', label = 'test accuracy history')
plt.legend(loc = 'lower right')
plt.title('accuracy history')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
batch_size = 560
lenet = LeNet2().to(device)
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
test_accuracy = []
test_loss = []
for epoch in bar(range(50), desc = 'learning'):
  indexs = np.random.permutation(len(train_data))
  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()
    batch_index = indexs[start_index: start_index + batch_size]
    labels_batch = train_labels[batch_index].to(device)

    images_batch = train_data[batch_index].to(device)
    prediction = lenet.forward(images_batch)
    loss_value = loss(prediction, labels_batch)
    loss_value.backward()
    optimizer.step()

  prediction_test = lenet.forward(test_data)
  test_loss.append(loss(prediction_test, test_labels).data.cpu())

  test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

  test_accuracy.append(test_acc)
# Out:
# <ipython-input-13-b12ac03f0692>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(50), desc = 'learning'):
# learning:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.figure(figsize= (16.0, 6.0))
plt.plot(range(50), test_accuracy, c = 'red', label = 'test accuracy history')
plt.legend(loc = 'lower right')
plt.title('accuracy history')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
batch_size = 560
lenet = LeNet3().to(device)
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
test_accuracy = []
test_loss = []
for epoch in bar(range(50), desc = 'learning'):
  indexs = np.random.permutation(len(train_data))
  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()
    batch_index = indexs[start_index: start_index + batch_size]
    labels_batch = train_labels[batch_index].to(device)

    images_batch = train_data[batch_index].to(device)
    prediction = lenet.forward(images_batch)
    loss_value = loss(prediction, labels_batch)
    loss_value.backward()
    optimizer.step()

  prediction_test = lenet.forward(test_data)
  test_loss.append(loss(prediction_test, test_labels).data.cpu())

  test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

  test_accuracy.append(test_acc)
# Out:
# <ipython-input-18-639c69e510e8>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(50), desc = 'learning'):
# learning:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.figure(figsize= (16.0, 6.0))
plt.plot(range(50), test_accuracy, c = 'red', label = 'test accuracy history')
plt.legend(loc = 'lower right')
plt.title('accuracy history')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
batch_size = 560
lenet = LeNet4().to(device)
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
test_accuracy = []
test_loss = []
for epoch in bar(range(50), desc = 'learning'):
  indexs = np.random.permutation(len(train_data))
  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()
    batch_index = indexs[start_index: start_index + batch_size]
    labels_batch = train_labels[batch_index].to(device)

    images_batch = train_data[batch_index].to(device)
    prediction = lenet.forward(images_batch)
    loss_value = loss(prediction, labels_batch)
    loss_value.backward()
    optimizer.step()

  prediction_test = lenet.forward(test_data)
  test_loss.append(loss(prediction_test, test_labels).data.cpu())

  test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

  test_accuracy.append(test_acc)
# Out:
# <ipython-input-20-fc508c0a791a>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(50), desc = 'learning'):
# learning:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.figure(figsize= (16.0, 6.0))
plt.plot(range(50), test_accuracy, c = 'red', label = 'test accuracy history')
plt.legend(loc = 'lower right')
plt.title('accuracy history')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
batch_size = 560
lenet = LeNet5().to(device)
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
test_accuracy = []
test_loss = []
for epoch in bar(range(50), desc = 'learning'):
  indexs = np.random.permutation(len(train_data))
  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()
    batch_index = indexs[start_index: start_index + batch_size]
    labels_batch = train_labels[batch_index].to(device)

    images_batch = train_data[batch_index].to(device)
    prediction = lenet.forward(images_batch)
    loss_value = loss(prediction, labels_batch)
    loss_value.backward()
    optimizer.step()

  prediction_test = lenet.forward(test_data)
  test_loss.append(loss(prediction_test, test_labels).data.cpu())

  test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

  test_accuracy.append(test_acc)
# Out:
# <ipython-input-24-321a8965fcd1>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(50), desc = 'learning'):
# learning:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.figure(figsize= (16.0, 6.0))
plt.plot(range(50), test_accuracy, c = 'red', label = 'test accuracy history')
plt.legend(loc = 'lower right')
plt.title('accuracy history')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
lenets =[LeNet1, LeNet2, LeNet3, LeNet4, LeNet5]
for nets in bar(range(5), desc = "Nets"):
    test_accuracy = []
    for experemets in bar(range(10), desc = "experiments"):
        batch_size = 560
        lenet = lenets[nets]().to(device)
        loss = torch.nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
        for epoch in range(100):
          indexs = np.random.permutation(len(train_data))
          for start_index in range(0, len(train_data), batch_size):
            optimizer.zero_grad()
            batch_index = indexs[start_index: start_index + batch_size]
            labels_batch = train_labels[batch_index].to(device)

            images_batch = train_data[batch_index].to(device)
            prediction = lenet.forward(images_batch)
            loss_value = loss(prediction, labels_batch)
            loss_value.backward()
            optimizer.step()

        prediction_test = lenet.forward(test_data)

        test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

        test_accuracy.append(test_acc)

        print(test_acc)

    print(*test_accuracy)
# Out:
# <ipython-input-28-b8d84ce065c3>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for nets in bar(range(5), desc = "Nets"):
# Nets:   0%|          | 0/5 [00:00<?, ?it/s]
# <ipython-input-28-b8d84ce065c3>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experemets in bar(range(10), desc = "experiments"):
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.6677)
# tensor(0.6691)
# tensor(0.6758)
# tensor(0.6885)
# tensor(0.6908)
# tensor(0.6819)
# tensor(0.6847)
# tensor(0.6882)
# tensor(0.6766)
# tensor(0.6814)
# tensor(0.6677) tensor(0.6691) tensor(0.6758) tensor(0.6885) tensor(0.6908) tensor(0.6819) tensor(0.6847) tensor(0.6882) tensor(0.6766) tensor(0.6814)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.6752)
# tensor(0.6736)
# tensor(0.6788)
# tensor(0.6673)
# tensor(0.6574)
# tensor(0.6710)
# tensor(0.6819)
# tensor(0.6807)
# tensor(0.6697)
# tensor(0.6737)
# tensor(0.6752) tensor(0.6736) tensor(0.6788) tensor(0.6673) tensor(0.6574) tensor(0.6710) tensor(0.6819) tensor(0.6807) tensor(0.6697) tensor(0.6737)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.7087)
# tensor(0.6966)
# tensor(0.6915)
# tensor(0.7020)
# tensor(0.7055)
# tensor(0.6693)
# tensor(0.6879)
# tensor(0.6836)
# tensor(0.6801)
# tensor(0.6766)
# tensor(0.7087) tensor(0.6966) tensor(0.6915) tensor(0.7020) tensor(0.7055) tensor(0.6693) tensor(0.6879) tensor(0.6836) tensor(0.6801) tensor(0.6766)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.7112)
# tensor(0.7220)
# tensor(0.6880)
# tensor(0.7239)
# tensor(0.7103)
# tensor(0.7119)
# tensor(0.7168)
# tensor(0.7150)
# tensor(0.7108)
# tensor(0.7233)
# tensor(0.7112) tensor(0.7220) tensor(0.6880) tensor(0.7239) tensor(0.7103) tensor(0.7119) tensor(0.7168) tensor(0.7150) tensor(0.7108) tensor(0.7233)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.7015)
# tensor(0.7060)
# tensor(0.7078)
# tensor(0.7057)
# tensor(0.7144)
# tensor(0.7204)
# tensor(0.7172)
# tensor(0.7160)
# tensor(0.7231)
# tensor(0.7045)
# tensor(0.7015) tensor(0.7060) tensor(0.7078) tensor(0.7057) tensor(0.7144) tensor(0.7204) tensor(0.7172) tensor(0.7160) tensor(0.7231) tensor(0.7045)

# %%
sample1 = "tensor(0.6677) tensor(0.6691) tensor(0.6758) tensor(0.6885) tensor(0.6908) tensor(0.6819) tensor(0.6847) tensor(0.6882) tensor(0.6766) tensor(0.6814)"
sample2 = "tensor(0.6752) tensor(0.6736) tensor(0.6788) tensor(0.6673) tensor(0.6574) tensor(0.6710) tensor(0.6819) tensor(0.6807) tensor(0.6697) tensor(0.6737)"
sample3 = "tensor(0.7087) tensor(0.6966) tensor(0.6915) tensor(0.7020) tensor(0.7055) tensor(0.6693) tensor(0.6879) tensor(0.6836) tensor(0.6801) tensor(0.6766)"
sample4 = "tensor(0.7112) tensor(0.7220) tensor(0.6880) tensor(0.7239) tensor(0.7103) tensor(0.7119) tensor(0.7168) tensor(0.7150) tensor(0.7108) tensor(0.7233)"
sample5 = "tensor(0.7015) tensor(0.7060) tensor(0.7078) tensor(0.7057) tensor(0.7144) tensor(0.7204) tensor(0.7172) tensor(0.7160) tensor(0.7231) tensor(0.7045)"

# %%
samples = [sample1, sample2, sample3, sample4, sample5]
for i in range(len(samples)):
    samples[i] = samples[i].replace("tensor(", '')
    samples[i] = samples[i].replace(')', '')
    samples[i] = [float(j) for j in samples[i].split(" ")]

# %%
plt.figure(figsize = (16., 6.))
plt.boxplot(samples)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7975b23b87f0>,
#   <matplotlib.lines.Line2D at 0x7975b23b8550>,
#   <matplotlib.lines.Line2D at 0x7975b23f0100>,
#   <matplotlib.lines.Line2D at 0x7975b23f03a0>,
#   <matplotlib.lines.Line2D at 0x7975b23f1360>,
#   <matplotlib.lines.Line2D at 0x7975b23f1600>,
#   <matplotlib.lines.Line2D at 0x7975b23f25c0>,
#   <matplotlib.lines.Line2D at 0x7975b23f2860>,
#   <matplotlib.lines.Line2D at 0x7975b23f3820>,
#   <matplotlib.lines.Line2D at 0x7975b23f3ac0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7975b23b82b0>,
#   <matplotlib.lines.Line2D at 0x7975b23bb610>,
#   <matplotlib.lines.Line2D at 0x7975b23f0640>,
#   <matplotlib.lines.Line2D at 0x7975b23f08e0>,
#   <matplotlib.lines.Line2D at 0x7975b23f18a0>,
#   <matplotlib.lines.Line2D at 0x7975b23f1b40>,
#   <matplotlib.lines.Line2D at 0x7975b23f2b00>,
#   <matplotlib.lines.Line2D at 0x7975b23f2da0>,
#   <matplotlib.lines.Line2D at 0x7975b23f3d60>,
#   <matplotlib.lines.Line2D at 0x7975b2428040>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7975b23b8a90>,
#   <matplotlib.lines.Line2D at 0x7975b23bbe20>,
#   <matplotlib.lines.Line2D at 0x7975b23f10c0>,
#   <matplotlib.lines.Line2D at 0x7975b23f2320>,
#   <matplotlib.lines.Line2D at 0x7975b23f3580>],
#  'medians': [<matplotlib.lines.Line2D at 0x7975b23bb8b0>,
#   <matplotlib.lines.Line2D at 0x7975b23f0b80>,
#   <matplotlib.lines.Line2D at 0x7975b23f1de0>,
#   <matplotlib.lines.Line2D at 0x7975b23f3040>,
#   <matplotlib.lines.Line2D at 0x7975b24282e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7975b23bbb50>,
#   <matplotlib.lines.Line2D at 0x7975b23f0e20>,
#   <matplotlib.lines.Line2D at 0x7975b23f2080>,
#   <matplotlib.lines.Line2D at 0x7975b23f32e0>,
#   <matplotlib.lines.Line2D at 0x7975b2428580>],
#  'means': []}

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.040448739231948076

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[2])
p_val
# Out:
# 0.06028947980326378

# %%
t_stat, p_val = stats.ttest_ind(samples[2], samples[3])
p_val
# Out:
# 0.00034989230102458035

# %%
t_stat, p_val = stats.ttest_ind(samples[3], samples[4])
p_val
# Out:
# 0.6857198785468885

# %% [markdown]
# # Second exploration

# %%
class LeNet6(torch.nn.Module):
  def __init__(self):
    super(LeNet6, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 0)
    self.act2 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()

    self.conv4 = torch.nn.Conv2d(in_channels = 6, out_channels = 9, kernel_size = 3, padding = 0)
    self.act4 = torch.nn.Tanh()
    self.conv5 = torch.nn.Conv2d(in_channels = 9, out_channels = 9, kernel_size = 3, padding = 1)
    self.act5 = torch.nn.Tanh()

    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act6 = torch.nn.Tanh()

    self.conv6 = torch.nn.Conv2d(in_channels = 9, out_channels = 12, kernel_size = 3, padding = 1)
    self.act7 = torch.nn.Tanh()
    self.conv7 = torch.nn.Conv2d(in_channels = 12, out_channels = 16, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()

    self.conv8 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()
    self.conv9 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act10 = torch.nn.Tanh()

    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act11 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act12 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act13 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)

    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)

    x = self.pool1(x)
    x = self.act6(x)

    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)

    x = self.pool2(x)
    x = self.act11(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act12(x)
    x = self.fc2(x)
    x = self.act13(x)
    x = self.fc3(x)

    return x

class LeNet7(torch.nn.Module):
  def __init__(self):
    super(LeNet7, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 0)
    self.act2 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()

    self.conv4 = torch.nn.Conv2d(in_channels = 6, out_channels = 9, kernel_size = 3, padding = 0)
    self.act4 = torch.nn.Tanh()
    self.conv5 = torch.nn.Conv2d(in_channels = 9, out_channels = 9, kernel_size = 3, padding = 1)
    self.act5 = torch.nn.Tanh()

    self.pool1 = torch.nn.MaxPool2d(kernel_size = 2, stride = 2)
    self.act6 = torch.nn.Tanh()

    self.conv6 = torch.nn.Conv2d(in_channels = 9, out_channels = 12, kernel_size = 3, padding = 1)
    self.act7 = torch.nn.Tanh()
    self.conv7 = torch.nn.Conv2d(in_channels = 12, out_channels = 16, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()

    self.conv8 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()
    self.conv9 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act10 = torch.nn.Tanh()

    self.pool2 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act11 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act12 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act13 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)

    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)

    x = self.pool1(x)
    x = self.act6(x)

    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)

    x = self.pool2(x)
    x = self.act11(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act12(x)
    x = self.fc2(x)
    x = self.act13(x)
    x = self.fc3(x)

    return x

class LeNet8(torch.nn.Module):
  def __init__(self):
    super(LeNet8, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 0)
    self.act2 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()

    self.conv4 = torch.nn.Conv2d(in_channels = 6, out_channels = 9, kernel_size = 3, padding = 0)
    self.act4 = torch.nn.Tanh()
    self.conv5 = torch.nn.Conv2d(in_channels = 9, out_channels = 9, kernel_size = 3, padding = 1)
    self.act5 = torch.nn.Tanh()

    self.pool1 = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
    self.act6 = torch.nn.Tanh()

    self.conv6 = torch.nn.Conv2d(in_channels = 9, out_channels = 12, kernel_size = 3, padding = 1)
    self.act7 = torch.nn.Tanh()
    self.conv7 = torch.nn.Conv2d(in_channels = 12, out_channels = 16, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()

    self.conv8 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()
    self.conv9 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act10 = torch.nn.Tanh()

    self.pool2 = torch.nn.MaxPool2d(kernel_size = 2, stride = 2)
    self.act11 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act12 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act13 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)

    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)

    x = self.pool1(x)
    x = self.act6(x)

    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)

    x = self.pool2(x)
    x = self.act11(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act12(x)
    x = self.fc2(x)
    x = self.act13(x)
    x = self.fc3(x)

    return x

class LeNet9(torch.nn.Module):
  def __init__(self):
    super(LeNet9, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 3, kernel_size = 3, padding = 1)
    self.act1 = torch.nn.Tanh()
    self.conv2 = torch.nn.Conv2d(in_channels = 3, out_channels = 6, kernel_size = 3, padding = 0)
    self.act2 = torch.nn.Tanh()
    self.conv3 = torch.nn.Conv2d(in_channels = 6, out_channels = 6, kernel_size = 3, padding = 1)
    self.act3 = torch.nn.Tanh()

    self.conv4 = torch.nn.Conv2d(in_channels = 6, out_channels = 9, kernel_size = 3, padding = 0)
    self.act4 = torch.nn.Tanh()
    self.conv5 = torch.nn.Conv2d(in_channels = 9, out_channels = 9, kernel_size = 3, padding = 1)
    self.act5 = torch.nn.Tanh()

    self.pool1 = torch.nn.MaxPool2d(kernel_size = 2, stride = 2)
    self.act6 = torch.nn.Tanh()

    self.conv6 = torch.nn.Conv2d(in_channels = 9, out_channels = 12, kernel_size = 3, padding = 1)
    self.act7 = torch.nn.Tanh()
    self.conv7 = torch.nn.Conv2d(in_channels = 12, out_channels = 16, kernel_size = 3, padding = 0)
    self.act8 = torch.nn.Tanh()

    self.conv8 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act9 = torch.nn.Tanh()
    self.conv9 = torch.nn.Conv2d(in_channels = 16, out_channels = 16, kernel_size = 3, padding = 1)
    self.act10 = torch.nn.Tanh()

    self.pool2 = torch.nn.MaxPool2d(kernel_size = 2, stride = 2)
    self.act11 = torch.nn.Tanh()
    self.fc1 = torch.nn.Linear(400, 120)
    self.act12 = torch.nn.Tanh()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act13 = torch.nn.Tanh()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)

    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)

    x = self.pool1(x)
    x = self.act6(x)

    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)

    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)

    x = self.pool2(x)
    x = self.act11(x)

    x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
    x = self.fc1(x)
    x = self.act12(x)
    x = self.fc2(x)
    x = self.act13(x)
    x = self.fc3(x)

    return x

# %%
lenets =[LeNet6, LeNet7, LeNet8, LeNet9]
for nets in bar(range(4), desc = "Nets"):
    test_accuracy = []
    for experemets in bar(range(10), desc = "experiments"):
        batch_size = 560
        lenet = lenets[nets]().to(device)
        loss = torch.nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(lenet.parameters(), lr = 0.001)
        for epoch in range(100):
          indexs = np.random.permutation(len(train_data))
          for start_index in range(0, len(train_data), batch_size):
            optimizer.zero_grad()
            batch_index = indexs[start_index: start_index + batch_size]
            labels_batch = train_labels[batch_index].to(device)

            images_batch = train_data[batch_index].to(device)
            prediction = lenet.forward(images_batch)
            loss_value = loss(prediction, labels_batch)
            loss_value.backward()
            optimizer.step()

        prediction_test = lenet.forward(test_data)

        test_acc = (prediction_test.argmax(dim = 1) == test_labels).float().mean().data.cpu()

        test_accuracy.append(test_acc)

        print(test_acc)

    print(*test_accuracy)
# Out:
# <ipython-input-39-4ae4a291cd50>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for nets in bar(range(4), desc = "Nets"):
# Nets:   0%|          | 0/4 [00:00<?, ?it/s]
# <ipython-input-39-4ae4a291cd50>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experemets in bar(range(10), desc = "experiments"):
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.6931)
# tensor(0.7193)
# tensor(0.6862)
# tensor(0.7095)
# tensor(0.7050)
# tensor(0.7154)
# tensor(0.7132)
# tensor(0.7001)
# tensor(0.7178)
# tensor(0.7084)
# tensor(0.6931) tensor(0.7193) tensor(0.6862) tensor(0.7095) tensor(0.7050) tensor(0.7154) tensor(0.7132) tensor(0.7001) tensor(0.7178) tensor(0.7084)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.7090)
# tensor(0.7037)
# tensor(0.7296)
# tensor(0.7104)
# tensor(0.7129)
# tensor(0.7047)
# tensor(0.6963)
# tensor(0.7165)
# tensor(0.7147)
# tensor(0.7063)
# tensor(0.7090) tensor(0.7037) tensor(0.7296) tensor(0.7104) tensor(0.7129) tensor(0.7047) tensor(0.6963) tensor(0.7165) tensor(0.7147) tensor(0.7063)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.6984)
# tensor(0.6919)
# tensor(0.6997)
# tensor(0.6955)
# tensor(0.6873)
# tensor(0.7036)
# tensor(0.7079)
# tensor(0.7070)
# tensor(0.7114)
# tensor(0.7060)
# tensor(0.6984) tensor(0.6919) tensor(0.6997) tensor(0.6955) tensor(0.6873) tensor(0.7036) tensor(0.7079) tensor(0.7070) tensor(0.7114) tensor(0.7060)
# experiments:   0%|          | 0/10 [00:00<?, ?it/s]
# tensor(0.7067)
# tensor(0.6788)
# tensor(0.6841)
# tensor(0.6961)
# tensor(0.7001)
# tensor(0.6925)
# tensor(0.7200)
# tensor(0.7051)
# tensor(0.7035)
# tensor(0.6987)
# tensor(0.7067) tensor(0.6788) tensor(0.6841) tensor(0.6961) tensor(0.7001) tensor(0.6925) tensor(0.7200) tensor(0.7051) tensor(0.7035) tensor(0.6987)

# %%
sample1 = "tensor(0.6931) tensor(0.7193) tensor(0.6862) tensor(0.7095) tensor(0.7050) tensor(0.7154) tensor(0.7132) tensor(0.7001) tensor(0.7178) tensor(0.7084)"
sample2 = "tensor(0.7090) tensor(0.7037) tensor(0.7296) tensor(0.7104) tensor(0.7129) tensor(0.7047) tensor(0.6963) tensor(0.7165) tensor(0.7147) tensor(0.7063)"
sample3 = "tensor(0.6984) tensor(0.6919) tensor(0.6997) tensor(0.6955) tensor(0.6873) tensor(0.7036) tensor(0.7079) tensor(0.7070) tensor(0.7114) tensor(0.7060)"
sample4 = "tensor(0.7067) tensor(0.6788) tensor(0.6841) tensor(0.6961) tensor(0.7001) tensor(0.6925) tensor(0.7200) tensor(0.7051) tensor(0.7035) tensor(0.6987)"

# %%
samples = [sample1, sample2, sample3, sample4]
for i in range(len(samples)):
    samples[i] = samples[i].replace("tensor(", '')
    samples[i] = samples[i].replace(')', '')
    samples[i] = [float(j) for j in samples[i].split(" ")]

# %%
plt.figure(figsize = (16., 6.))
plt.boxplot(samples)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7975b2118970>,
#   <matplotlib.lines.Line2D at 0x7975b2118c10>,
#   <matplotlib.lines.Line2D at 0x7975b2119bd0>,
#   <matplotlib.lines.Line2D at 0x7975b2119e70>,
#   <matplotlib.lines.Line2D at 0x7975b211ae30>,
#   <matplotlib.lines.Line2D at 0x7975b211b0d0>,
#   <matplotlib.lines.Line2D at 0x7975b20780d0>,
#   <matplotlib.lines.Line2D at 0x7975b2078370>],
#  'caps': [<matplotlib.lines.Line2D at 0x7975b2118eb0>,
#   <matplotlib.lines.Line2D at 0x7975b2119150>,
#   <matplotlib.lines.Line2D at 0x7975b211a110>,
#   <matplotlib.lines.Line2D at 0x7975b211a3b0>,
#   <matplotlib.lines.Line2D at 0x7975b211b370>,
#   <matplotlib.lines.Line2D at 0x7975b211b610>,
#   <matplotlib.lines.Line2D at 0x7975b2078610>,
#   <matplotlib.lines.Line2D at 0x7975b20788b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7975b21186d0>,
#   <matplotlib.lines.Line2D at 0x7975b2119930>,
#   <matplotlib.lines.Line2D at 0x7975b211ab90>,
#   <matplotlib.lines.Line2D at 0x7975b211bdf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7975b21193f0>,
#   <matplotlib.lines.Line2D at 0x7975b211a650>,
#   <matplotlib.lines.Line2D at 0x7975b211b8b0>,
#   <matplotlib.lines.Line2D at 0x7975b2078b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7975b2119690>,
#   <matplotlib.lines.Line2D at 0x7975b211a8f0>,
#   <matplotlib.lines.Line2D at 0x7975b211bb50>,
#   <matplotlib.lines.Line2D at 0x7975b2078df0>],
#  'means': []}

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.42852953685531736
