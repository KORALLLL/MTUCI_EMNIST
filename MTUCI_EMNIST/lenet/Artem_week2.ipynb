# %% [markdown]
# <a href="https://colab.research.google.com/github/KORALLLL/MTUCI_EMNIST/blob/Artem/MTUCI_EMNIST/lenet/Artem_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***CONVOLUTION EXPERIMENT***

# %% [markdown]
# Model #1

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>6</th>
#     <th>28*28</th>
#     <th>5*5</th>
#     <th>1</th>
#     <th>2</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>avg pooling</th>
#     <th>6</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>5*5</th>
#     <th>1</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>tanh</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #2

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>avg pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #3

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>avg pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #4

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>avg pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #5

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>avg pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# **Train dataset:** MNIST + EMNIST letters
#
# **Test dataset:** dataset of DreamTeam
#
# **Training sample size:** 36960
#
# **Testing sample size:** 16784
#
# **Loss function:** Cross Entropy Loss
#
# **Optimizer:** Adam
#
# **Learning rate:** 1.0e-3
#
# **Batch size:** 1120
#
# **Epoch number:** 100

# %% [markdown]
# ***IMPORT***
#
# ---

# %%
import torch
import torchvision.datasets
import random
import numpy as np
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm_notebook as bar

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ***REPO***
#
# ---

# %%
# !git clone https://github.com/KORALLLL/MTUCI_EMNIST.git
# Out:
# Cloning into 'MTUCI_EMNIST'...
# remote: Enumerating objects: 36449, done.
# remote: Counting objects: 100% (12809/12809), done.
# remote: Compressing objects: 100% (12692/12692), done.
# remote: Total 36449 (delta 157), reused 12688 (delta 112), pack-reused 23640
# Receiving objects: 100% (36449/36449), 128.44 MiB | 17.48 MiB/s, done.
# Resolving deltas: 100% (442/442), done.

# %% [markdown]
# ***TORCH.DEVICE***
#
# ---

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ***DATASET***
#
# ---

# %%
emnist_train = torchvision.datasets.EMNIST('./', split='letters', download = True, train = True)
mnist_train = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = True)
emnist_val = torchvision.datasets.EMNIST('./', split='letters', download = True, train = False)
mnist_val = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = False)

emnist_train_data = emnist_train.data
mnist_train_data = mnist_train.data
train_data = torch.cat([emnist_train_data[:24960], mnist_train_data[:12000]], dim=0).float().unsqueeze(1).to(device) / 255

emnist_val_data = emnist_val.data
mnist_val_data = mnist_val.data
val_data = torch.cat([emnist_val_data, mnist_val_data], dim=0).float().unsqueeze(1).to(device) / 255

temp_emnist_train_labels = emnist_train.targets[:24960]
emnist_train_labels = []

temp_emnist_val_labels = emnist_val.targets
emnist_val_labels = []

for i in range(len(temp_emnist_train_labels)):
  if temp_emnist_train_labels[i]==15:
    emnist_train_labels.append(torch.tensor(0))
  elif temp_emnist_train_labels[i]>15:
    emnist_train_labels.append(temp_emnist_train_labels[i]+8)
  else:
    emnist_train_labels.append(temp_emnist_train_labels[i]+9)

for i in range(len(temp_emnist_val_labels)):
  if temp_emnist_val_labels[i]==15:
    emnist_val_labels.append(torch.tensor(0))
  elif temp_emnist_val_labels[i]>15:
    emnist_val_labels.append(temp_emnist_val_labels[i] + 8)
  else:
    emnist_val_labels.append(temp_emnist_val_labels[i]+9)

mnist_train_labels = mnist_train.targets
train_labels = torch.cat([torch.stack(emnist_train_labels[:24960]), mnist_train_labels[:12000]], dim=0).to(device)

mnist_val_labels = mnist_val.targets
val_labels = torch.cat([torch.stack(emnist_val_labels), mnist_val_labels], dim=0).to(device)


file = open('MTUCI_EMNIST/dataset.pkl', 'rb')
test_dataset = pickle.load(file)
file.close()

test_data = test_dataset['data'].numpy()
test_data = np.flip(test_data, axis = 3)
test_data = np.rot90(test_data, k=1, axes=(2,3))
test_data = 1 - test_data
test_data = torch.from_numpy(test_data).float().to(device)
test_labels = test_dataset['targets'].to(device)
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to ./EMNIST/raw/gzip.zip
# 100%|██████████| 561753746/561753746 [00:23<00:00, 24207820.06it/s]
# Extracting ./EMNIST/raw/gzip.zip to ./EMNIST/raw

# %% [markdown]
# ***SHOW VAL_DATA***
#
# ---

# %%
plt.imshow(val_data.cpu()[1][0])
plt.show()

# %% [markdown]
# ***NEURAL NETWORK***
#
# ---

# %%
class LeNet1(torch.nn.Module):
    def __init__(self):
        super(LeNet1, self).__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, padding=2)
        self.act1  = torch.nn.Tanh()
        self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0)
        self.act2  = torch.nn.Tanh()
        self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        self.fc1   = torch.nn.Linear(5 * 5 * 16, 120)
        self.act3  = torch.nn.Tanh()
        self.fc2   = torch.nn.Linear(120, 84)
        self.act4  = torch.nn.Tanh()
        self.fc3   = torch.nn.Linear(84, 35)

    def forward(self, x):
        x = self.conv1(x)
        x = self.act1(x)
        x = self.pool1(x)
        x = self.conv2(x)
        x = self.act2(x)
        x = self.pool2(x)
        x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
        x = self.fc1(x)
        x = self.act3(x)
        x = self.fc2(x)
        x = self.act4(x)
        x = self.fc3(x)
        return x

# %%
class LeNet2(torch.nn.Module):
  def __init__(self):
    super(LeNet2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act3 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act4 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act5 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act6 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(5*5*16, 120)
    self.act7 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act8 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.pool1(x)
    x = self.act3(x)
    x = self.conv3(x)
    x = self.act4(x)
    x = self.conv4(x)
    x = self.act5(x)
    x = self.pool2(x)
    x = self.act6(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act7(x)
    x = self.fc2(x)
    x = self.act8(x)
    x = self.fc3(x)
    return x

# %%
class LeNet3(torch.nn.Module):
  def __init__(self):
    super(LeNet3, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act4 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act7 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act8 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(5*5*16, 120)
    self.act9 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120,84)
    self.act10 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.pool1(x)
    x = self.act4(x)
    x = self.conv4(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.pool2(x)
    x = self.act8(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act9(x)
    x = self.fc2(x)
    x = self.act10(x)
    x = self.fc3(x)
    return x

# %%
class LeNet4(torch.nn.Module):
  def __init__(self):
    super(LeNet4, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act10 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act11 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.pool1(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.pool2(x)
    x = self.act10(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)
    return x

# %%
class LeNet5(torch.nn.Module):
  def __init__(self):
    super(LeNet5,self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, padding=1)
    self.act5 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.conv9 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act10 = torch.nn.ReLU()
    self.conv10 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act11 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act12 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act13 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act14 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self,x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.conv5(x)
    x = self.act5(x)
    x = self.pool1(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.conv9(x)
    x = self.act10(x)
    x = self.conv10(x)
    x = self.act11(x)
    x = self.pool2(x)
    x = self.act12(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act13(x)
    x = self.fc2(x)
    x = self.act14(x)
    x = self.fc3(x)
    return x

# %% [markdown]
# ***NETS & PLOTS***
#
# ---

# %% [markdown]
# *Model #1*

# %%
lenet1 = LeNet1().to(device)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet1.parameters(), lr=1.0e-3)

for epoch in bar(range(100), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet1.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet1.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-21-eb0e8fad592c>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(100), desc='learning'):
# learning:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(100), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 100)
# Out:
# (30.0, 100.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(100), test_loss_history)

# %% [markdown]
# *Model #2*

# %%
lenet2 = LeNet2().to(device)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet2.parameters(), lr=1.0e-3)

for epoch in bar(range(200), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet2.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet2.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-26-8b417de2592f>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(200), desc='learning'):
# learning:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 200)
# Out:
# (30.0, 200.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_loss_history)

# %% [markdown]
# *Model #3*

# %%
lenet3 = LeNet3().to(device)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet3.parameters(), lr=1.0e-3)

for epoch in bar(range(200), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet3.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet3.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-29-bd19d369b2ae>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(200), desc='learning'):
# learning:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 200)
# Out:
# (30.0, 200.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_loss_history)

# %% [markdown]
# *Model #4*

# %%
lenet4 = LeNet4().to(device)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet4.parameters(), lr=1.0e-3)

for epoch in bar(range(200), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet4.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet4.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-42-4838710beb80>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(200), desc='learning'):
# learning:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 200)
# Out:
# (30.0, 200.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_loss_history)

# %% [markdown]
# *Model #5*

# %%
lenet5 = LeNet5().to(device)
test_accuracy_history = []
test_loss_history = []
batch_size = 1120
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet5.parameters(), lr=1.0e-3)

for epoch in bar(range(200), desc='learning'):
  order = np.random.permutation(len(train_data))

  for start_index in range(0, len(train_data), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    data_batch = train_data[batch_indexes]
    labels_batch= train_labels[batch_indexes]

    preds = lenet5.forward(data_batch)

    loss_val = loss(preds, labels_batch)
    loss_val.backward()

    optimizer.step()

  test_preds = lenet5.forward(test_data)
  test_loss = loss(test_preds, test_labels).data.cpu()

  accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
  test_accuracy_history.append(accuracy)
  test_loss_history.append(test_loss)
# Out:
# <ipython-input-51-021c0c65b442>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in bar(range(200), desc='learning'):
# learning:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_accuracy_history)
plt.ylim(0.6, 0.7)
plt.xlim(30, 200)
# Out:
# (30.0, 200.0)

# %%
plt.figure(figsize=(16.0, 6.0))
plt.plot(range(200), test_loss_history)

# %% [markdown]
# **ALL MODELS**

# %%
models = [LeNet1, LeNet2, LeNet3, LeNet4, LeNet5]

for model in bar(range(5), desc = 'MODELS'):
  accuracy_net = []
  for experiment in bar(range(20), desc = 'EXPERIMENT'):

    lenet = models[model]().to(device)
    loss = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(lenet.parameters(), lr=0.001)
    batch_size = 1120

    for epoch in range(100):
      order = np.random.permutation(len(train_data))

      for start_index in range(0, len(train_data), batch_size):
        optimizer.zero_grad()

        batch_indexes = order[start_index:start_index+batch_size]

        data_batch = train_data[batch_indexes]
        labels_batch= train_labels[batch_indexes]

        preds = lenet.forward(data_batch)

        loss_val = loss(preds, labels_batch)
        loss_val.backward()

        optimizer.step()

    test_preds = lenet.forward(test_data)
    accuracy = (test_preds.argmax(dim=1)==test_labels).float().mean().data.cpu()
    accuracy_net.append(accuracy)
  print(f'ACCURACY OF {model+1} MODEL:\n', *accuracy_net)
  samples[model] = list(map(float, (str(accuracy_net).replace("tensor(", '').replace(')', '').replace("[","").replace("]", "")).split(", ")))
# Out:
# <ipython-input-92-3ff8f630fe0b>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for model in bar(range(5), desc = 'MODELS'):
# MODELS:   0%|          | 0/5 [00:00<?, ?it/s]
# <ipython-input-92-3ff8f630fe0b>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in bar(range(20), desc = 'EXPERIMENT'):
# EXPERIMENT:   0%|          | 0/20 [00:00<?, ?it/s]
# ACCURACY OF 1 MODEL:
#  tensor(0.6709) tensor(0.6815) tensor(0.6840) tensor(0.6692) tensor(0.6739) tensor(0.6692) tensor(0.6811) tensor(0.6832) tensor(0.6913) tensor(0.6691) tensor(0.6612) tensor(0.6800) tensor(0.6695) tensor(0.6687) tensor(0.6824) tensor(0.6904) tensor(0.6793) tensor(0.6761) tensor(0.6802) tensor(0.6869)
# EXPERIMENT:   0%|          | 0/20 [00:00<?, ?it/s]
# ACCURACY OF 2 MODEL:
#  tensor(0.6692) tensor(0.6068) tensor(0.6438) tensor(0.6444) tensor(0.6449) tensor(0.6600) tensor(0.6549) tensor(0.0499) tensor(0.4858) tensor(0.6411) tensor(0.6685) tensor(0.6557) tensor(0.6368) tensor(0.6828) tensor(0.6502) tensor(0.6404) tensor(0.6539) tensor(0.6398) tensor(0.6634) tensor(0.6646)
# EXPERIMENT:   0%|          | 0/20 [00:00<?, ?it/s]
# ACCURACY OF 3 MODEL:
#  tensor(0.6491) tensor(0.0499) tensor(0.6647) tensor(0.6618) tensor(0.6880) tensor(0.6623) tensor(0.6468) tensor(0.6702) tensor(0.6772) tensor(0.6615) tensor(0.6414) tensor(0.6926) tensor(0.6642) tensor(0.6929) tensor(0.6822) tensor(0.6750) tensor(0.6687) tensor(0.6953) tensor(0.0499) tensor(0.6624)
# EXPERIMENT:   0%|          | 0/20 [00:00<?, ?it/s]
samples = [acc1,acc2,acc3,acc4,acc5]
for i in range(5):
    samples[i] = list(map(float, samples[i].replace("tensor(", '').replace(')', '').replace("[","").replace("]", "").split()))
print(samples[0])
print(samples[1])
print(samples[2])
print(samples[3])
print(samples[4])
# Out:
# [0.6709, 0.6815, 0.684, 0.6692, 0.6739, 0.6692, 0.6811, 0.6832, 0.6913, 0.6691, 0.6612, 0.68, 0.6695, 0.6687, 0.6824, 0.6904, 0.6793, 0.6761, 0.6802, 0.6869]
# [0.6692, 0.6068, 0.6438, 0.6444, 0.6449, 0.66, 0.6549, 0.4858, 0.6411, 0.6685, 0.6557, 0.6368, 0.6828, 0.6502, 0.6404, 0.6539, 0.6398, 0.6634, 0.6646]
# [0.6491, 0.6647, 0.6618, 0.688, 0.6623, 0.6468, 0.6702, 0.6772, 0.6615, 0.6414, 0.6926, 0.6642, 0.6929, 0.6822, 0.675, 0.6687, 0.6953, 0.6624]
# [0.6744, 0.6663, 0.6862, 0.6915, 0.6607, 0.6748, 0.6708, 0.6816, 0.6922, 0.702, 0.6906, 0.589, 0.6708, 0.6806, 0.6865, 0.6826, 0.6676, 0.5683, 0.6655]
# [0.6751, 0.6593, 0.6949, 0.6339, 0.687, 0.6632, 0.6292, 0.6733]

# %%
plt.figure(figsize = (16.,6.))
plt.boxplot(samples)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77fc435c0ac0>,
#   <matplotlib.lines.Line2D at 0x77fc435c0d60>,
#   <matplotlib.lines.Line2D at 0x77fc435c1d20>,
#   <matplotlib.lines.Line2D at 0x77fc435c1fc0>,
#   <matplotlib.lines.Line2D at 0x77fc435c2f80>,
#   <matplotlib.lines.Line2D at 0x77fc435c3220>,
#   <matplotlib.lines.Line2D at 0x77fc435fc220>,
#   <matplotlib.lines.Line2D at 0x77fc435fc4c0>,
#   <matplotlib.lines.Line2D at 0x77fc435fd480>,
#   <matplotlib.lines.Line2D at 0x77fc435fd720>],
#  'caps': [<matplotlib.lines.Line2D at 0x77fc435c1000>,
#   <matplotlib.lines.Line2D at 0x77fc435c12a0>,
#   <matplotlib.lines.Line2D at 0x77fc435c2260>,
#   <matplotlib.lines.Line2D at 0x77fc435c2500>,
#   <matplotlib.lines.Line2D at 0x77fc435c34c0>,
#   <matplotlib.lines.Line2D at 0x77fc435c3760>,
#   <matplotlib.lines.Line2D at 0x77fc435fc760>,
#   <matplotlib.lines.Line2D at 0x77fc435fca00>,
#   <matplotlib.lines.Line2D at 0x77fc435fd9c0>,
#   <matplotlib.lines.Line2D at 0x77fc435fdc60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x77fc435c0820>,
#   <matplotlib.lines.Line2D at 0x77fc435c1a80>,
#   <matplotlib.lines.Line2D at 0x77fc435c2ce0>,
#   <matplotlib.lines.Line2D at 0x77fc435c3f40>,
#   <matplotlib.lines.Line2D at 0x77fc435fd1e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x77fc435c1540>,
#   <matplotlib.lines.Line2D at 0x77fc435c27a0>,
#   <matplotlib.lines.Line2D at 0x77fc435c3a00>,
#   <matplotlib.lines.Line2D at 0x77fc435fcca0>,
#   <matplotlib.lines.Line2D at 0x77fc435fdf00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77fc435c17e0>,
#   <matplotlib.lines.Line2D at 0x77fc435c2a40>,
#   <matplotlib.lines.Line2D at 0x77fc435c3ca0>,
#   <matplotlib.lines.Line2D at 0x77fc435fcf40>,
#   <matplotlib.lines.Line2D at 0x77fc435fe1a0>],
#  'means': []}

# %%
import scipy.stats as stats

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.0006723974417799602

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[2])
p_val
# Out:
# 0.06849299642472241

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[3])
p_val
# Out:
# 0.2591554081333973

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[4])
p_val
# Out:
# 0.03643344080135358

# %% [markdown]
# ***POOLING EXPERIMENT***

# %% [markdown]
# Model #4_1

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>avg pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #4_2

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>avg pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>max pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #4_3

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>max pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>max pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# Model #4_4

# %% [markdown]
# <table>
#   <tr>
#     <th>Layer</th>
#     <th>Layer type2</th>
#     <th>Feature maps</th>
#     <th>Size</th>
#     <th>Kernel size</th>
#     <th>Stride</th>
#     <th>Padding</th>
#     <th>Activation</th>
#   </tr>
#   <tr>
#     <th>input</th>
#     <th>image</th>
#     <th>1</th>
#     <th>28*28</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>convolution</th>
#     <th>2</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>convolution</th>
#     <th>4</th>
#     <th>28*28</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>max pooling</th>
#     <th>4</th>
#     <th>14*14</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>convolution</th>
#     <th>8</th>
#     <th>12*12</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>convolution</th>
#     <th>16</th>
#     <th>10*10</th>
#     <th>3*3</th>
#     <th>1</th>
#     <th>1</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>avg pooling</th>
#     <th>16</th>
#     <th>5*5</th>
#     <th>2*2</th>
#     <th>2</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>120</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>84</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>ReLU</th>
#   </tr>
#   <tr>
#     <th>output</th>
#     <th>fully connected</th>
#     <th>-</th>
#     <th>35</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#     <th>-</th>
#   </tr>
# </table>

# %% [markdown]
# **Train dataset:** MNIST + EMNIST letters
#
# **Test dataset:** dataset of DreamTeam
#
# **Training sample size:** 36960
#
# **Testing sample size:** 16784
#
# **Loss function:** Cross Entropy Loss
#
# **Optimizer:** Adam
#
# **Learning rate:** 1.0e-3
#
# **Batch size:** 1120
#
# **Epoch number:** 100

# %% [markdown]
# ***IMPORT***
#
# ---

# %%
import torch
import torchvision.datasets
import random
import numpy as np
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm_notebook as bar

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ***REPO***
#
# ---

# %%
# !git clone https://github.com/KORALLLL/MTUCI_EMNIST.git
# Out:
# Cloning into 'MTUCI_EMNIST'...
# remote: Enumerating objects: 36457, done.
# remote: Counting objects: 100% (12817/12817), done.
# remote: Compressing objects: 100% (12700/12700), done.
# remote: Total 36457 (delta 158), reused 12688 (delta 112), pack-reused 23640
# Receiving objects: 100% (36457/36457), 129.07 MiB | 6.94 MiB/s, done.
# Resolving deltas: 100% (443/443), done.

# %% [markdown]
# ***TORCH.DEVICE***
#
# ---

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ***DATASET***
#
# ---

# %%
emnist_train = torchvision.datasets.EMNIST('./', split='letters', download = True, train = True)
mnist_train = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = True)
emnist_val = torchvision.datasets.EMNIST('./', split='letters', download = True, train = False)
mnist_val = torchvision.datasets.EMNIST('./', split='mnist', download = True, train = False)

emnist_train_data = emnist_train.data
mnist_train_data = mnist_train.data
train_data = torch.cat([emnist_train_data[:24960], mnist_train_data[:12000]], dim=0).float().unsqueeze(1).to(device) / 255

emnist_val_data = emnist_val.data
mnist_val_data = mnist_val.data
val_data = torch.cat([emnist_val_data, mnist_val_data], dim=0).float().unsqueeze(1).to(device) / 255

temp_emnist_train_labels = emnist_train.targets[:24960]
emnist_train_labels = []

temp_emnist_val_labels = emnist_val.targets
emnist_val_labels = []

for i in range(len(temp_emnist_train_labels)):
  if temp_emnist_train_labels[i]==15:
    emnist_train_labels.append(torch.tensor(0))
  elif temp_emnist_train_labels[i]>15:
    emnist_train_labels.append(temp_emnist_train_labels[i]+8)
  else:
    emnist_train_labels.append(temp_emnist_train_labels[i]+9)

for i in range(len(temp_emnist_val_labels)):
  if temp_emnist_val_labels[i]==15:
    emnist_val_labels.append(torch.tensor(0))
  elif temp_emnist_val_labels[i]>15:
    emnist_val_labels.append(temp_emnist_val_labels[i] + 8)
  else:
    emnist_val_labels.append(temp_emnist_val_labels[i]+9)

mnist_train_labels = mnist_train.targets
train_labels = torch.cat([torch.stack(emnist_train_labels[:24960]), mnist_train_labels[:12000]], dim=0).to(device)

mnist_val_labels = mnist_val.targets
val_labels = torch.cat([torch.stack(emnist_val_labels), mnist_val_labels], dim=0).to(device)


file = open('MTUCI_EMNIST/dataset.pkl', 'rb')
test_dataset = pickle.load(file)
file.close()

test_data = test_dataset['data'].numpy()
test_data = np.flip(test_data, axis = 3)
test_data = np.rot90(test_data, k=1, axes=(2,3))
test_data = 1 - test_data
test_data = torch.from_numpy(test_data).float().to(device)
test_labels = test_dataset['targets'].to(device)
# Out:
# Downloading https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/gzip.zip to ./EMNIST/raw/gzip.zip
# 100%|██████████| 561753746/561753746 [00:15<00:00, 37011820.00it/s]
# Extracting ./EMNIST/raw/gzip.zip to ./EMNIST/raw

# %% [markdown]
# ***NEURAL NETWORK***
#
# ---

# %%
class LeNet4_1(torch.nn.Module):
  def __init__(self):
    super(LeNet4_1, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act10 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act11 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.pool1(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.pool2(x)
    x = self.act10(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)
    return x

# %%
class LeNet4_2(torch.nn.Module):
  def __init__(self):
    super(LeNet4_2, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act10 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act11 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.pool1(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.pool2(x)
    x = self.act10(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)
    return x

# %%
class LeNet4_3(torch.nn.Module):
  def __init__(self):
    super(LeNet4_3, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.pool2 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act10 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act11 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.pool1(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.pool2(x)
    x = self.act10(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)
    return x

# %%
class LeNet4_4(torch.nn.Module):
  def __init__(self):
    super(LeNet4_4, self).__init__()
    self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, padding=1)
    self.act1 = torch.nn.ReLU()
    self.conv2 = torch.nn.Conv2d(in_channels=2, out_channels=2, kernel_size=3, padding=1)
    self.act2 = torch.nn.ReLU()
    self.conv3 = torch.nn.Conv2d(in_channels=2, out_channels=4, kernel_size=3, padding=1)
    self.act3 = torch.nn.ReLU()
    self.conv4 = torch.nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, padding=1)
    self.act4 = torch.nn.ReLU()
    self.pool1 = torch.nn.MaxPool2d(kernel_size=2, stride=2)
    self.act5 = torch.nn.ReLU()
    self.conv5 = torch.nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding=0)
    self.act6 = torch.nn.ReLU()
    self.conv6 = torch.nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
    self.act7 = torch.nn.ReLU()
    self.conv7 = torch.nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0)
    self.act8 = torch.nn.ReLU()
    self.conv8 = torch.nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
    self.act9 = torch.nn.ReLU()
    self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
    self.act10 = torch.nn.ReLU()
    self.fc1 = torch.nn.Linear(16*5*5, 120)
    self.act11 = torch.nn.ReLU()
    self.fc2 = torch.nn.Linear(120, 84)
    self.act12 = torch.nn.ReLU()
    self.fc3 = torch.nn.Linear(84, 35)

  def forward(self, x):
    x = self.conv1(x)
    x = self.act1(x)
    x = self.conv2(x)
    x = self.act2(x)
    x = self.conv3(x)
    x = self.act3(x)
    x = self.conv4(x)
    x = self.act4(x)
    x = self.pool1(x)
    x = self.act5(x)
    x = self.conv5(x)
    x = self.act6(x)
    x = self.conv6(x)
    x = self.act7(x)
    x = self.conv7(x)
    x = self.act8(x)
    x = self.conv8(x)
    x = self.act9(x)
    x = self.pool2(x)
    x = self.act10(x)
    x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
    x = self.fc1(x)
    x = self.act11(x)
    x = self.fc2(x)
    x = self.act12(x)
    x = self.fc3(x)
    return x

# %% [markdown]
acc4 = "tensor(0.6177) tensor(0.6598) tensor(0.7010) tensor(0.6745) tensor(0.6019) tensor(0.6803) tensor(0.6519) tensor(0.6780) tensor(0.6828) tensor(0.6537) tensor(0.6987) tensor(0.6842) tensor(0.6675) tensor(0.7113) tensor(0.6770) tensor(0.6484) tensor(0.6887)"
samples = [acc1,acc2,acc3,acc4]
for i in range(4):
    samples[i] = list(map(float, samples[i].replace("tensor(", '').replace(')', '').replace("[","").replace("]", "").split()))
print(samples[0])
print(samples[1])
print(samples[2])
print(samples[3])
# Out:
# [0.6739, 0.6384, 0.6632, 0.5757, 0.6862, 0.6745, 0.6635, 0.69, 0.6742, 0.6933, 0.6674, 0.6496, 0.6905, 0.6841, 0.6379, 0.6756, 0.6762]
# [0.683, 0.6831, 0.7141, 0.7024, 0.6178, 0.7038, 0.6919, 0.7147, 0.6691, 0.6431, 0.6899, 0.6979, 0.6776, 0.6906, 0.6776, 0.6876, 0.7034]
# [0.6933, 0.6967, 0.6624, 0.6666, 0.6837, 0.709, 0.6965, 0.7015, 0.695, 0.6794, 0.6877, 0.6967, 0.7002, 0.6926, 0.6871, 0.692, 0.6124, 0.6759]
# [0.6177, 0.6598, 0.701, 0.6745, 0.6019, 0.6803, 0.6519, 0.678, 0.6828, 0.6537, 0.6987, 0.6842, 0.6675, 0.7113, 0.677, 0.6484, 0.6887]

# %%
plt.figure(figsize = (16.,4.))
plt.boxplot(samples)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79727ef4e6e0>,
#   <matplotlib.lines.Line2D at 0x79727ef4e980>,
#   <matplotlib.lines.Line2D at 0x79727ef4f850>,
#   <matplotlib.lines.Line2D at 0x79727ef4faf0>,
#   <matplotlib.lines.Line2D at 0x79727ef9caf0>,
#   <matplotlib.lines.Line2D at 0x79727ef9cd90>,
#   <matplotlib.lines.Line2D at 0x79727ef9dd50>,
#   <matplotlib.lines.Line2D at 0x79727ef9e020>],
#  'caps': [<matplotlib.lines.Line2D at 0x79727ef4ec20>,
#   <matplotlib.lines.Line2D at 0x79727ef4eec0>,
#   <matplotlib.lines.Line2D at 0x79727ef4fd90>,
#   <matplotlib.lines.Line2D at 0x79727ef9c070>,
#   <matplotlib.lines.Line2D at 0x79727ef9d030>,
#   <matplotlib.lines.Line2D at 0x79727ef9d2d0>,
#   <matplotlib.lines.Line2D at 0x79727ef9e2c0>,
#   <matplotlib.lines.Line2D at 0x79727ef9e560>],
#  'boxes': [<matplotlib.lines.Line2D at 0x79727ef4e440>,
#   <matplotlib.lines.Line2D at 0x79727ef4f5b0>,
#   <matplotlib.lines.Line2D at 0x79727ef9c850>,
#   <matplotlib.lines.Line2D at 0x79727ef9dab0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79727ef4f160>,
#   <matplotlib.lines.Line2D at 0x79727ef9c310>,
#   <matplotlib.lines.Line2D at 0x79727ef9d570>,
#   <matplotlib.lines.Line2D at 0x79727ef9e800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79727ef4f400>,
#   <matplotlib.lines.Line2D at 0x79727ef9c5b0>,
#   <matplotlib.lines.Line2D at 0x79727ef9d810>,
#   <matplotlib.lines.Line2D at 0x79727ef9eaa0>],
#  'means': []}

# %%
import scipy.stats as stats

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[1])
p_val
# Out:
# 0.0394224416170481

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[2])
p_val
# Out:
# 0.02989179353294646

# %%
t_stat, p_val = stats.ttest_ind(samples[0], samples[3])
p_val
# Out:
# 0.7063859460907583
